# %%
import pandas as pd
import os

directory = 'experiments_results\models'

csv_files = [file for file in os.listdir(directory)]
classification_df = pd.DataFrame()
regression_df = pd.DataFrame()

for filename in csv_files:
    if 'results_classification_' in filename:
        df = pd.read_csv(os.path.join(directory, filename))
        df['source_file'] = filename.replace('results_classification_', "")
        classification_df = pd.concat([classification_df, df], ignore_index=True)
    elif 'results_regression_' in filename:
        df = pd.read_csv(os.path.join(directory, filename))
        df['source_file'] = filename.replace('results_regression_', "")
        regression_df = pd.concat([regression_df, df], ignore_index=True)

classification_df.drop('Unnamed: 0', axis=1, inplace=True)
regression_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
classification_df.head()
# Out:
#                            Classifier  Accuracy         source_file
# 0  RandomForestClassifier-50-None-2-1    0.8111  descriptors_sc.csv
# 1  RandomForestClassifier-50-None-2-2    0.8170  descriptors_sc.csv
# 2  RandomForestClassifier-50-None-2-4    0.8111  descriptors_sc.csv
# 3  RandomForestClassifier-50-None-5-1    0.8124  descriptors_sc.csv
# 4  RandomForestClassifier-50-None-5-2    0.8150  descriptors_sc.csv

# %%
classification_df['Classifier_name'] = classification_df['Classifier'].str.split('-').str[0]
classification_df['Parameters'] = classification_df['Classifier'].str.split('-').str[1:].str.join('-')

# %%
classification_df.head()
# Out:
#                            Classifier  Accuracy         source_file  \
# 0  RandomForestClassifier-50-None-2-1    0.8111  descriptors_sc.csv
# 1  RandomForestClassifier-50-None-2-2    0.8170  descriptors_sc.csv
# 2  RandomForestClassifier-50-None-2-4    0.8111  descriptors_sc.csv
# 3  RandomForestClassifier-50-None-5-1    0.8124  descriptors_sc.csv
# 4  RandomForestClassifier-50-None-5-2    0.8150  descriptors_sc.csv
#
#           Classifier_name   Parameters
# 0  RandomForestClassifier  50-None-2-1
# 1  RandomForestClassifier  50-None-2-2
# 2  RandomForestClassifier  50-None-2-4
# 3  RandomForestClassifier  50-None-5-1
# 4  RandomForestClassifier  50-None-5-2

# %%
df_sorted = classification_df.sort_values(by='Accuracy', ascending=False).groupby('Classifier_name').apply(lambda x: x.sort_values(by='Accuracy', ascending=False))

# %%
df_sorted.drop('Classifier_name', axis=1, inplace=True)
df_sorted.drop('Classifier', axis=1, inplace=True)

# %%
for group_name, group_df in df_sorted.groupby('Classifier_name'):
    print(f"Group: {group_name}")
    print(group_df.head(10))
    print("\n")
# Out:
# Group: GradientBoostingClassifier
#                                 Accuracy            source_file Parameters
# Classifier_name
# GradientBoostingClassifier 505    0.8216    fingerprints_sc.csv    100-0.1
#                            509    0.8170    fingerprints_sc.csv    200-0.1
#                            163    0.8150     descriptors_sc.csv    100-0.1
#                            168    0.8117     descriptors_sc.csv    200-0.5
#                            502    0.8104    fingerprints_sc.csv     10-0.5
#                            167    0.8104     descriptors_sc.csv    200-0.1
#                            164    0.8078     descriptors_sc.csv    100-0.5
#                            339    0.8038  descriptors_scpca.csv    200-0.5
#                            335    0.8025  descriptors_scpca.csv    100-0.5
#                            169    0.8018     descriptors_sc.csv    200-1.0
#
#
# Group: LogisticRegression
#                         Accuracy             source_file          Parameters
# Classifier_name
# LogisticRegression 432    0.8203     fingerprints_sc.csv         0.1-l1-saga
#                    425    0.8176     fingerprints_sc.csv  0.001-l2-liblinear
#                    596    0.8176  fingerprints_scpca.csv  0.001-l2-liblinear
#                    597    0.8163  fingerprints_scpca.csv       0.001-l2-saga
#                    87     0.8157      descriptors_sc.csv   0.01-l2-liblinear
#                    88     0.8150      descriptors_sc.csv        0.01-l2-saga
#                    603    0.8137  fingerprints_scpca.csv         0.1-l1-saga
#                    426    0.8130     fingerprints_sc.csv       0.001-l2-saga
#                    92     0.8124      descriptors_sc.csv         0.1-l2-saga
#                    98     0.8117      descriptors_sc.csv          10-l1-saga
#
#
# Group: MLPClassifier
#                      Accuracy            source_file                Parameters
# Classifier_name
# MLPClassifier   139    0.8183     descriptors_sc.csv      (100,)-tanh-0.01-500
#                 309    0.8176  descriptors_scpca.csv      (100,)-tanh-0.01-200
#                 137    0.8163     descriptors_sc.csv    (100,)-tanh-0.001-1000
#                 132    0.8163     descriptors_sc.csv    (100,)-tanh-0.0001-200
#                 312    0.8150  descriptors_scpca.csv  (50, 50)-relu-0.0001-200
#                 120    0.8150     descriptors_sc.csv       (50,)-tanh-0.01-200
#                 118    0.8150     descriptors_sc.csv      (50,)-tanh-0.001-500
#                 311    0.8150  descriptors_scpca.csv     (100,)-tanh-0.01-1000
#                 158    0.8130     descriptors_sc.csv   (50, 50)-tanh-0.01-1000
#                 135    0.8130     descriptors_sc.csv     (100,)-tanh-0.001-200
#
#
# Group: RandomForestClassifier
#                             Accuracy          source_file     Parameters
# Classifier_name
# RandomForestClassifier 54     0.8236   descriptors_sc.csv   200-None-2-1
#                        70     0.8229   descriptors_sc.csv    200-10-10-2
#                        79     0.8223   descriptors_sc.csv    200-20-10-2
#                        63     0.8216   descriptors_sc.csv     200-10-2-1
#                        55     0.8216   descriptors_sc.csv   200-None-2-2
#                        61     0.8216   descriptors_sc.csv  200-None-10-2
#                        373    0.8216  fingerprints_sc.csv   100-None-5-2
#                        67     0.8216   descriptors_sc.csv     200-10-5-2
#                        75     0.8216   descriptors_sc.csv     200-20-5-1
#                        402    0.8209  fingerprints_sc.csv  200-None-10-1

# %%
regression_df.head()
# Out:
#                             Classifier                       Accuracy  \
# 0  LinearRegression-0.001-l1-liblinear  -23804644783006964252672.0000
# 1   MLPRegressor-(50,)-relu-0.0001-200                        -1.5518
# 2   MLPRegressor-(50,)-relu-0.0001-500                        -1.2417
# 3  MLPRegressor-(50,)-relu-0.0001-1000                        -1.1356
# 4    MLPRegressor-(50,)-relu-0.001-200                        -1.1921
#
#           source_file
# 0  descriptors_sc.csv
# 1  descriptors_sc.csv
# 2  descriptors_sc.csv
# 3  descriptors_sc.csv
# 4  descriptors_sc.csv

# %%
regression_df['Classifier_name'] = regression_df['Classifier'].str.split('-').str[0]
regression_df['Parameters'] = regression_df['Classifier'].str.split('-').str[1:].str.join('-')

# %%
regression_df.head()
# Out:
#                             Classifier                       Accuracy  \
# 0  LinearRegression-0.001-l1-liblinear  -23804644783006964252672.0000
# 1   MLPRegressor-(50,)-relu-0.0001-200                        -1.5518
# 2   MLPRegressor-(50,)-relu-0.0001-500                        -1.2417
# 3  MLPRegressor-(50,)-relu-0.0001-1000                        -1.1356
# 4    MLPRegressor-(50,)-relu-0.001-200                        -1.1921
#
#           source_file   Classifier_name              Parameters
# 0  descriptors_sc.csv  LinearRegression      0.001-l1-liblinear
# 1  descriptors_sc.csv      MLPRegressor   (50,)-relu-0.0001-200
# 2  descriptors_sc.csv      MLPRegressor   (50,)-relu-0.0001-500
# 3  descriptors_sc.csv      MLPRegressor  (50,)-relu-0.0001-1000
# 4  descriptors_sc.csv      MLPRegressor    (50,)-relu-0.001-200

# %%
regression_df.dtypes
# Out:
# Classifier          object
# Accuracy           float64
# source_file         object
# Classifier_name     object
# Parameters          object
# dtype: object

# %%
regression_df['Accuracy'] = regression_df['Accuracy'].abs()

# %%
regression_df.sort_values(by='Accuracy', ascending=False)
# Out:
#                               Classifier      Accuracy  \
# 377  LinearRegression-0.001-l1-liblinear  2.399973e+24
# 0    LinearRegression-0.001-l1-liblinear  2.380464e+22
# 525  LinearRegression-0.001-l1-liblinear  8.014320e+01
# 591    GradientBoostingRegressor-200-2.0  6.791030e+01
# 391    MLPRegressor-(50,)-tanh-0.001-500  6.751140e+01
# ..                                   ...           ...
# 369     RandomForestRegressor-200-20-2-2  6.258000e-01
# 368     RandomForestRegressor-200-20-2-1  6.240000e-01
# 140    GradientBoostingRegressor-100-0.1  6.182000e-01
# 350   RandomForestRegressor-200-None-2-1  6.165000e-01
# 144    GradientBoostingRegressor-200-0.1  6.134000e-01
#
#                 source_file            Classifier_name            Parameters
# 377     fingerprints_sc.csv           LinearRegression    0.001-l1-liblinear
# 0        descriptors_sc.csv           LinearRegression    0.001-l1-liblinear
# 525  fingerprints_scpca.csv           LinearRegression    0.001-l1-liblinear
# 591  fingerprints_scpca.csv  GradientBoostingRegressor               200-2.0
# 391     fingerprints_sc.csv               MLPRegressor  (50,)-tanh-0.001-500
# ..                      ...                        ...                   ...
# 369     fingerprints_sc.csv      RandomForestRegressor            200-20-2-2
# 368     fingerprints_sc.csv      RandomForestRegressor            200-20-2-1
# 140      descriptors_sc.csv  GradientBoostingRegressor               100-0.1
# 350     fingerprints_sc.csv      RandomForestRegressor          200-None-2-1
# 144      descriptors_sc.csv  GradientBoostingRegressor               200-0.1
#
# [592 rows x 5 columns]

# %%
df_sorted = regression_df.sort_values(by='Accuracy', ascending=False).groupby('Classifier_name').apply(lambda x: x.sort_values(by='Accuracy', ascending=False))

# %%
df_sorted.drop('Classifier_name', axis=1, inplace=True)
df_sorted.drop('Classifier', axis=1, inplace=True)

# %%
df_sorted
# Out:
#                                Accuracy             source_file    Parameters
# Classifier_name
# GradientBoostingRegressor 591   67.9103  fingerprints_scpca.csv       200-2.0
#                           439    3.9598     fingerprints_sc.csv       100-2.0
#                           443    3.7254     fingerprints_sc.csv       200-2.0
#                           587    3.4377  fingerprints_scpca.csv       100-2.0
#                           583    2.8763  fingerprints_scpca.csv        10-2.0
# ...                                 ...                     ...           ...
# RandomForestRegressor     353    0.6267     fingerprints_sc.csv  200-None-5-1
#                           323    0.6267     fingerprints_sc.csv  100-None-2-1
#                           369    0.6258     fingerprints_sc.csv    200-20-2-2
#                           368    0.6240     fingerprints_sc.csv    200-20-2-1
#                           350    0.6165     fingerprints_sc.csv  200-None-2-1
#
# [592 rows x 3 columns]

# %%
for group_name, group_df in df_sorted.groupby('Classifier_name'):
    print(f"Group: {group_name}")
    print(group_df.head(10))
    print("\n")
# Out:
# Group: GradientBoostingRegressor
#                                Accuracy             source_file Parameters
# Classifier_name
# GradientBoostingRegressor 591   67.9103  fingerprints_scpca.csv    200-2.0
#                           439    3.9598     fingerprints_sc.csv    100-2.0
#                           443    3.7254     fingerprints_sc.csv    200-2.0
#                           587    3.4377  fingerprints_scpca.csv    100-2.0
#                           583    2.8763  fingerprints_scpca.csv     10-2.0
#                           147    2.4976      descriptors_sc.csv    200-2.0
#                           143    2.4803      descriptors_sc.csv    100-2.0
#                           139    2.4298      descriptors_sc.csv     10-2.0
#                           291    2.3050   descriptors_scpca.csv    100-2.0
#                           295    2.3050   descriptors_scpca.csv    200-2.0
#
#
# Group: LinearRegression
#                           Accuracy             source_file          Parameters
# Classifier_name
# LinearRegression 377  2.399973e+24     fingerprints_sc.csv  0.001-l1-liblinear
#                  0    2.380464e+22      descriptors_sc.csv  0.001-l1-liblinear
#                  525  8.014320e+01  fingerprints_scpca.csv  0.001-l1-liblinear
#                  229  8.406000e-01   descriptors_scpca.csv  0.001-l1-liblinear
#
#
# Group: MLPRegressor
#                      Accuracy          source_file              Parameters
# Classifier_name
# MLPRegressor    391   67.5114  fingerprints_sc.csv    (50,)-tanh-0.001-500
#                 395   65.7909  fingerprints_sc.csv    (50,)-tanh-0.01-1000
#                 389   65.4082  fingerprints_sc.csv  (50,)-tanh-0.0001-1000
#                 387   64.8598  fingerprints_sc.csv   (50,)-tanh-0.0001-200
#                 392   62.0853  fingerprints_sc.csv   (50,)-tanh-0.001-1000
#                 412   61.2790  fingerprints_sc.csv    (100,)-tanh-0.01-500
#                 394   61.0124  fingerprints_sc.csv     (50,)-tanh-0.01-500
#                 413   60.5579  fingerprints_sc.csv   (100,)-tanh-0.01-1000
#                 408   60.4817  fingerprints_sc.csv   (100,)-tanh-0.001-200
#                 411   60.2411  fingerprints_sc.csv    (100,)-tanh-0.01-200
#
#
# Group: RandomForestRegressor
#                            Accuracy             source_file    Parameters
# Classifier_name
# RandomForestRegressor 458    0.8699  fingerprints_scpca.csv     50-10-5-4
#                       467    0.8677  fingerprints_scpca.csv     50-20-5-4
#                       463    0.8590  fingerprints_scpca.csv     50-20-2-2
#                       454    0.8582  fingerprints_scpca.csv     50-10-2-2
#                       460    0.8549  fingerprints_scpca.csv    50-10-10-2
#                       461    0.8521  fingerprints_scpca.csv    50-10-10-4
#                       455    0.8518  fingerprints_scpca.csv     50-10-2-4
#                       473    0.8498  fingerprints_scpca.csv  100-None-2-4
#                       453    0.8498  fingerprints_scpca.csv     50-10-2-1
#                       457    0.8496  fingerprints_scpca.csv     50-10-5-2
