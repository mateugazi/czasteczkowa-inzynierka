# %% [markdown]
# # Imports

# %%
import warnings
from itertools import product

import numpy as np
import pandas as pd
from mordred import Calculator, descriptors
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.decomposition import PCA
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import (StratifiedKFold, KFold,
                                     cross_val_score, train_test_split)
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.preprocessing import StandardScaler

warnings.filterwarnings("ignore", category=Warning)

N_SPLITS = 2
RANDOM_STATE = 148260

# %%
def CalculateMorganFingerprint(mol):
    mfpgen = AllChem.GetMorganGenerator(radius=2,fpSize=2048)
    fingerprint = np.array([mfpgen.GetFingerprintAsNumPy(x) for x in mol])
    fingerprint = pd.DataFrame(fingerprint, columns = ['mfp'+str(i) for i in range(fingerprint.shape[1])])
    return fingerprint

# %%
def CalculateDescriptors(mol):
    calc = Calculator(descriptors, ignore_3D=False)
    X_mordred = calc.pandas(mol, nproc=1)
    X_mordred = X_mordred.select_dtypes(['number'])
    #normalize
    X_mordred = (X_mordred-X_mordred.min())/(X_mordred.max()-X_mordred.min())
    #drop columns wth low std
    X_mordred = X_mordred.loc[:,X_mordred.std()>0.01]
    return X_mordred

# %%
def LoadDatasetCSV(path, threshold=7.0, regression = False):
    df = pd.read_csv(path)
    df['molecule_from_smiles'] = df['smiles'].apply(Chem.MolFromSmiles)
    df['smiles'] = df['smiles'].map(lambda x: Chem.MolToSmiles(Chem.MolFromSmiles(x)))
    df.drop_duplicates('smiles')
    df = df.dropna()
    if regression:
        df['Target'] = df['pIC50']
    else:
        df['Target'] = df['pIC50'] > threshold
    return df

# %%
def split_data(df, approach = 'desc', split = 0.7):
    #TODO: support for different approaches - if applicable
    if approach == 'desc':
        X = CalculateDescriptors(df['molecule_from_smiles'])
    else:
        X = CalculateMorganFingerprint(df['molecule_from_smiles'])
    y = df["Target"]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=(1-split), random_state=42)
    return X_train, y_train, X_test, y_test

# %%
def run_rf(X, y, n_estimators, max_depth, min_samples_split, min_samples_leaf, regression=False):
    if regression:
        name = "RandomForestRegressor"
        model = RandomForestRegressor(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf)
        cv = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
        scoring = 'neg_mean_squared_error'
    else:
        name = "RandomForestClassifier"
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf)
        cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
        scoring = 'accuracy'
    scores = cross_val_score(model, X, y, cv=cv, scoring=scoring)
    mean_accuracy = scores.mean()
    return (f"{name}-{n_estimators}-{max_depth}-{min_samples_split}-{min_samples_leaf}; {mean_accuracy:.4f}")

def run_lr(X, y, C, penalty, solver, regression=False):
    if regression:
        name = "LinearRegression"
        model = LinearRegression()
        cv = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
        scoring = 'neg_mean_squared_error'
    else:
        name = "LogisticRegression"
        model = LogisticRegression(C=C, penalty=penalty, solver=solver)
        cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
        scoring = 'accuracy'
    scores = cross_val_score(model, X, y, cv=cv, scoring=scoring)
    mean_accuracy = scores.mean()
    return (f"{name}-{C}-{penalty}-{solver}; {mean_accuracy:.4f}")

def run_nn(X, y, hidden_layer_sizes, activation, alpha, max_iter, regression=False):
    if regression:
        name = "MLPRegressor"
        model = MLPRegressor(hidden_layer_sizes=hidden_layer_sizes, activation=activation, alpha=alpha, max_iter=max_iter)
        cv = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
        scoring = 'neg_mean_squared_error'
    else:
        name = "MLPClassifier"
        model = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, activation=activation, alpha=alpha, max_iter=max_iter)
        cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
        scoring = 'accuracy'
    scores = cross_val_score(model, X, y, cv=cv, scoring=scoring)
    mean_accuracy = scores.mean()
    return (f"{name}-{hidden_layer_sizes}-{activation}-{alpha}-{max_iter}; {mean_accuracy:.4f}")

def run_gb(X, y, n_estimators, learning_rate, regression=False):
    if regression:
        name = "GradientBoostingRegressor"
        model = GradientBoostingRegressor(n_estimators=n_estimators, learning_rate=learning_rate)
        cv = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
        scoring = 'neg_mean_squared_error'
    else:
        name = "GradientBoostingClassifier"
        model = GradientBoostingClassifier(n_estimators=n_estimators, learning_rate=learning_rate)
        cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
        scoring = 'accuracy'
    scores = cross_val_score(model, X, y, cv=cv, scoring=scoring)
    mean_accuracy = scores.mean()
    return (f"{name}-{n_estimators}-{learning_rate}; {mean_accuracy:.4f}")

# %%
from sklearn.svm import SVR
from sklearn.svm import SVC

def run_svm(X, y, c, d, regression=False):
    if regression:
        name = "SVR"
        model = SVR(C=c, degree=d, kernel="poly")
        cv = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
        scoring = 'neg_mean_squared_error'
    else:
        name = "SVC"
        model = SVC(C=c, degree=d, kernel="poly")
        cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
        scoring = 'accuracy'
    print("Eval\n")
    scores = cross_val_score(model, X, y, cv=cv, scoring=scoring)
    mean_accuracy = scores.mean()
    return (f"{name}-{c}-{d}; {mean_accuracy:.4f}")

# %%
data_classification = LoadDatasetCSV("data\processed\simple_input_data.csv")
data_classification.head()
# Out:
#                                               smiles     pIC50
# 0  Cc1ccccc1-c1ccc2nc(N)c(C[C@@H](C)C(=O)N[C@@H]3...  9.154901  \
# 1  CCCO[C@H]1C[NH2+][C@@H]([C@@H](O)[C@H](Cc2cc(F...  8.853872
# 2  CCc1cn2c3c(cc(C(=O)N[C@@H](Cc4ccccc4)[C@H](O)C...  8.698970
# 3  CCOC[C@@H](Oc1cc(C[C@@H]2CS(=O)(=O)C[C@H]([NH2...  8.698970
# 4  CCc1cn2c3c(cc(C(=O)N[C@@H](Cc4ccccc4)[C@H](O)C...  8.698970
#
#                                 molecule_from_smiles  Target
# 0  <rdkit.Chem.rdchem.Mol object at 0x000001F984B...    True
# 1  <rdkit.Chem.rdchem.Mol object at 0x000001F984B...    True
# 2  <rdkit.Chem.rdchem.Mol object at 0x000001F984B...    True
# 3  <rdkit.Chem.rdchem.Mol object at 0x000001F984B...    True
# 4  <rdkit.Chem.rdchem.Mol object at 0x000001F984B...    True

# %%
data_regression = LoadDatasetCSV("data\processed\simple_input_data.csv", regression=True)
data_regression.head()
# Out:
#                                               smiles     pIC50
# 0  Cc1ccccc1-c1ccc2nc(N)c(C[C@@H](C)C(=O)N[C@@H]3...  9.154901  \
# 1  CCCO[C@H]1C[NH2+][C@@H]([C@@H](O)[C@H](Cc2cc(F...  8.853872
# 2  CCc1cn2c3c(cc(C(=O)N[C@@H](Cc4ccccc4)[C@H](O)C...  8.698970
# 3  CCOC[C@@H](Oc1cc(C[C@@H]2CS(=O)(=O)C[C@H]([NH2...  8.698970
# 4  CCc1cn2c3c(cc(C(=O)N[C@@H](Cc4ccccc4)[C@H](O)C...  8.698970
#
#                                 molecule_from_smiles    Target
# 0  <rdkit.Chem.rdchem.Mol object at 0x000001F984B...  9.154901
# 1  <rdkit.Chem.rdchem.Mol object at 0x000001F984B...  8.853872
# 2  <rdkit.Chem.rdchem.Mol object at 0x000001F984B...  8.698970
# 3  <rdkit.Chem.rdchem.Mol object at 0x000001F984B...  8.698970
# 4  <rdkit.Chem.rdchem.Mol object at 0x000001F984B...  8.698970

# %%
X_train_desc_classification, y_train_desc_classification, X_test_desc_classification, y_test_desc_classification = split_data(data_classification)

# %%
X_train_desc_classification
# Out:
#            ABC     ABCGG  nAcid  nBase   SpAbs_A   SpMax_A  SpDiam_A
# 209   0.582920  0.571986   0.00   0.00  0.582398  0.456539  0.479510  \
# 613   0.366165  0.341732   0.00   0.25  0.373272  0.503185  0.528503
# 1131  0.234412  0.223823   0.00   0.50  0.216149  0.592990  0.622827
# 140   0.228498  0.219951   0.25   0.50  0.216418  0.555507  0.578297
# 1094  0.186547  0.188806   0.00   0.75  0.178725  0.656629  0.563294
# ...        ...       ...    ...    ...       ...       ...       ...
# 1130  0.331611  0.321370   0.00   0.25  0.322084  0.421017  0.442201
# 1294  0.309270  0.325988   0.00   0.00  0.309149  0.273714  0.287486
# 860   0.283667  0.268915   0.00   1.00  0.290459  0.861105  0.795958
# 1459  0.331611  0.321370   0.00   0.25  0.322084  0.421017  0.442201
# 1126  0.262532  0.248364   0.00   0.25  0.245483  0.797722  0.723946
#
#         SpAD_A   SpMAD_A   LogEE_A  ...     SRW10    TSRW10        MW
# 209   0.582398  0.446868  0.792690  ...  0.847445  0.521445  0.588711  \
# 613   0.373272  0.582010  0.631118  ...  0.719285  0.341022  0.362488
# 1131  0.216149  0.374746  0.486042  ...  0.694361  0.228140  0.220422
# 140   0.216418  0.561592  0.477725  ...  0.633569  0.333643  0.212989
# 1094  0.178725  0.527251  0.423776  ...  0.616091  0.312119  0.180768
# ...        ...       ...       ...  ...       ...       ...       ...
# 1130  0.322084  0.403183  0.595470  ...  0.696437  0.312289  0.335223
# 1294  0.309149  0.386712  0.572930  ...  0.573711  0.295718  0.306415
# 860   0.290459  0.927731  0.549717  ...  0.790551  0.402997  0.241079
# 1459  0.322084  0.403183  0.595470  ...  0.696437  0.312289  0.335223
# 1126  0.245483  0.465557  0.521640  ...  0.729421  0.375545  0.255968
#
#            AMW     WPath      WPol   Zagreb1  Zagreb2  mZagreb1  mZagreb2
# 209   0.407040  0.239499  0.604317  0.591743    0.596  0.565881  0.564214
# 613   0.351430  0.084586  0.381295  0.376147    0.384  0.280719  0.355700
# 1131  0.603534  0.032005  0.287770  0.256881    0.274  0.241499  0.194084
# 140   0.492783  0.025660  0.230216  0.247706    0.260  0.156298  0.184704
# 1094  0.622083  0.020099  0.230216  0.206422    0.226  0.177164  0.156566
# ...        ...       ...       ...       ...      ...       ...       ...
# 1130  0.362681  0.070607  0.345324  0.344037    0.348  0.321097  0.308081
# 1294  0.137594  0.063828  0.294964  0.302752    0.296  0.316847  0.311688
# 860   0.499394  0.034358  0.359712  0.321101    0.364  0.134660  0.233045
# 1459  0.362681  0.070607  0.345324  0.344037    0.348  0.321097  0.308081
# 1126  0.315944  0.037159  0.302158  0.288991    0.310  0.213679  0.217893
#
# [1063 rows x 1222 columns]

# %%
X_train_desc_regression, y_train_desc_regression, X_test_desc_regression, y_test_desc_regression = split_data(data_regression)

# %%
X_train_fp_classification, y_train_fp_classification, X_test_fp_classification, y_test_fp_classification = split_data(data_classification, approach = 'fp')

# %%
X_train_fp_regression, y_train_fp_regression, X_test_fp_regression, y_test_fp_regression = split_data(data_regression, approach = 'fp')

# %% [markdown]
# # Descriptors

# %%
import time

def run_experiment(regression=False, fingerprint=False, pca=False):
    sc = StandardScaler()

    if fingerprint:
        if regression:
            X = sc.fit_transform(pd.concat([X_train_fp_regression, X_test_fp_regression]))
            y = pd.concat([y_train_fp_regression, y_test_fp_regression])
            
        else:
            X = sc.fit_transform(pd.concat([X_train_fp_classification, X_test_fp_classification]))
            y = pd.concat([y_train_fp_classification, y_test_fp_classification])

    else:
        if regression:
            X = sc.fit_transform(pd.concat([X_train_desc_regression, X_test_desc_regression]))
            y = pd.concat([y_train_desc_regression, y_test_desc_regression])
            
        else:
            X = sc.fit_transform(pd.concat([X_train_desc_classification, X_test_desc_classification]))
            y = pd.concat([y_train_desc_classification, y_test_desc_classification])

    if pca:
        pca = PCA(n_components=0.95)
        X = pca.fit_transform(X)
        
    results = []
    param_grid_svm={
        #'gamma': [0.001, 0.1, 1], ### Gamma 100 C 0.1 degree 3 still loops and stalls
        'C': [0.01, 0.1, 1, 10, 100, 1000], # C >= 10 are problematic
        'degree': [2, 3, 4, 5]
    }

    param_combinations = list(product(*param_grid_svm.values()))
    for combination in param_combinations:
        c, d = combination
        print(f"\nRegression: {regression}, Fingerprint: {fingerprint}, PCA: {pca}")
        for index, key in enumerate(param_grid_svm.keys()):
            print(f"{key}: {combination[index]}, ", end="")
        start = time.time()
        results.append(run_svm(X, y, c, d, regression))
        print(f"\nAccuracy: {results[-1]}\n")
        end = time.time()
        print(f"Elapsed time: {round(end - start, 2)}s\n")


    csv_path = "results_"
    if regression: csv_path += "regression" 
    else: csv_path += "classification"
    if fingerprint: csv_path += "_fingerprints"
    else: csv_path += "_descriptors"
    csv_path += "_sc"
    if pca: csv_path += "pca"
    csv_path += "_svm.csv"

    data_tuples = [tuple(item.split('; ')) for item in results]
    df = pd.DataFrame(data_tuples, columns=['Classifier', 'Accuracy'])
    df.to_csv(csv_path)
    
    return results, csv_path

# %%
run_grid = {
        'regression': [False, True],
        'fingerprint': [False, True],
        'pca': [False, True]
    }

run_param_combinations = list(product(*run_grid.values()))

result_dict = {}

for combination in run_param_combinations:
    n, m, s = combination
    res, run_name = run_experiment(n, m, s)
    result_dict[run_name] = res
# Out:
# Regression: False, Fingerprint: False, PCA: False
# C: 0.01, degree: 2, Eval
#
#
# Accuracy: SVC-0.01-2; 0.5616
#
# Elapsed time: 0.32s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 0.01, degree: 3, Eval
#
#
# Accuracy: SVC-0.01-3; 0.5648
#
# Elapsed time: 0.3s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 0.01, degree: 4, Eval
#
#
# Accuracy: SVC-0.01-4; 0.5708
#
# Elapsed time: 0.3s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 0.01, degree: 5, Eval
#
#
# Accuracy: SVC-0.01-5; 0.5734
#
# Elapsed time: 0.3s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 0.1, degree: 2, Eval
#
#
# Accuracy: SVC-0.1-2; 0.6287
#
# Elapsed time: 0.29s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 0.1, degree: 3, Eval
#
#
# Accuracy: SVC-0.1-3; 0.6484
#
# Elapsed time: 0.28s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 0.1, degree: 4, Eval
#
#
# Accuracy: SVC-0.1-4; 0.5951
#
# Elapsed time: 0.3s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 0.1, degree: 5, Eval
#
#
# Accuracy: SVC-0.1-5; 0.5971
#
# Elapsed time: 0.3s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 1, degree: 2, Eval
#
#
# Accuracy: SVC-1-2; 0.7689
#
# Elapsed time: 0.24s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 1, degree: 3, Eval
#
#
# Accuracy: SVC-1-3; 0.7913
#
# Elapsed time: 0.24s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 1, degree: 4, Eval
#
#
# Accuracy: SVC-1-4; 0.7511
#
# Elapsed time: 0.26s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 1, degree: 5, Eval
#
#
# Accuracy: SVC-1-5; 0.7288
#
# Elapsed time: 0.27s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 10, degree: 2, Eval
#
#
# Accuracy: SVC-10-2; 0.7834
#
# Elapsed time: 0.21s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 10, degree: 3, Eval
#
#
# Accuracy: SVC-10-3; 0.7979
#
# Elapsed time: 0.21s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 10, degree: 4, Eval
#
#
# Accuracy: SVC-10-4; 0.7854
#
# Elapsed time: 0.24s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 10, degree: 5, Eval
#
#
# Accuracy: SVC-10-5; 0.7828
#
# Elapsed time: 0.23s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 100, degree: 2, Eval
#
#
# Accuracy: SVC-100-2; 0.7683
#
# Elapsed time: 0.2s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 100, degree: 3, Eval
#
#
# Accuracy: SVC-100-3; 0.7788
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 100, degree: 4, Eval
#
#
# Accuracy: SVC-100-4; 0.7939
#
# Elapsed time: 0.24s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 100, degree: 5, Eval
#
#
# Accuracy: SVC-100-5; 0.7893
#
# Elapsed time: 0.24s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 1000, degree: 2, Eval
#
#
# Accuracy: SVC-1000-2; 0.7637
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 1000, degree: 3, Eval
#
#
# Accuracy: SVC-1000-3; 0.7696
#
# Elapsed time: 0.2s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 1000, degree: 4, Eval
#
#
# Accuracy: SVC-1000-4; 0.7775
#
# Elapsed time: 0.24s
#
#
# Regression: False, Fingerprint: False, PCA: False
# C: 1000, degree: 5, Eval
#
#
# Accuracy: SVC-1000-5; 0.7729
#
# Elapsed time: 0.24s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 2, Eval
#
#
# Accuracy: SVC-0.01-2; 0.5616
#
# Elapsed time: 0.05s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 3, Eval
#
#
# Accuracy: SVC-0.01-3; 0.5675
#
# Elapsed time: 0.05s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 4, Eval
#
#
# Accuracy: SVC-0.01-4; 0.5714
#
# Elapsed time: 0.05s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 5, Eval
#
#
# Accuracy: SVC-0.01-5; 0.5747
#
# Elapsed time: 0.05s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 2, Eval
#
#
# Accuracy: SVC-0.1-2; 0.6340
#
# Elapsed time: 0.05s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 3, Eval
#
#
# Accuracy: SVC-0.1-3; 0.6557
#
# Elapsed time: 0.05s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 4, Eval
#
#
# Accuracy: SVC-0.1-4; 0.5997
#
# Elapsed time: 0.05s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 5, Eval
#
#
# Accuracy: SVC-0.1-5; 0.6004
#
# Elapsed time: 0.05s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1, degree: 2, Eval
#
#
# Accuracy: SVC-1-2; 0.7617
#
# Elapsed time: 0.04s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1, degree: 3, Eval
#
#
# Accuracy: SVC-1-3; 0.7900
#
# Elapsed time: 0.04s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1, degree: 4, Eval
#
#
# Accuracy: SVC-1-4; 0.7571
#
# Elapsed time: 0.05s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1, degree: 5, Eval
#
#
# Accuracy: SVC-1-5; 0.7367
#
# Elapsed time: 0.05s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 10, degree: 2, Eval
#
#
# Accuracy: SVC-10-2; 0.7749
#
# Elapsed time: 0.04s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 10, degree: 3, Eval
#
#
# Accuracy: SVC-10-3; 0.7992
#
# Elapsed time: 0.04s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 10, degree: 4, Eval
#
#
# Accuracy: SVC-10-4; 0.7907
#
# Elapsed time: 0.04s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 10, degree: 5, Eval
#
#
# Accuracy: SVC-10-5; 0.7887
#
# Elapsed time: 0.05s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 100, degree: 2, Eval
#
#
# Accuracy: SVC-100-2; 0.7597
#
# Elapsed time: 0.06s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 100, degree: 3, Eval
#
#
# Accuracy: SVC-100-3; 0.7788
#
# Elapsed time: 0.04s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 100, degree: 4, Eval
#
#
# Accuracy: SVC-100-4; 0.7861
#
# Elapsed time: 0.04s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 100, degree: 5, Eval
#
#
# Accuracy: SVC-100-5; 0.7814
#
# Elapsed time: 0.04s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1000, degree: 2, Eval
#
#
# Accuracy: SVC-1000-2; 0.7406
#
# Elapsed time: 0.06s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1000, degree: 3, Eval
#
#
# Accuracy: SVC-1000-3; 0.7485
#
# Elapsed time: 0.04s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1000, degree: 4, Eval
#
#
# Accuracy: SVC-1000-4; 0.7709
#
# Elapsed time: 0.04s
#
#
# Regression: False, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1000, degree: 5, Eval
#
#
# Accuracy: SVC-1000-5; 0.7676
#
# Elapsed time: 0.05s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 0.01, degree: 2, Eval
#
#
# Accuracy: SVC-0.01-2; 0.5609
#
# Elapsed time: 0.52s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 0.01, degree: 3, Eval
#
#
# Accuracy: SVC-0.01-3; 0.5609
#
# Elapsed time: 0.54s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 0.01, degree: 4, Eval
#
#
# Accuracy: SVC-0.01-4; 0.5609
#
# Elapsed time: 0.54s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 0.01, degree: 5, Eval
#
#
# Accuracy: SVC-0.01-5; 0.5609
#
# Elapsed time: 0.53s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 0.1, degree: 2, Eval
#
#
# Accuracy: SVC-0.1-2; 0.5609
#
# Elapsed time: 0.52s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 0.1, degree: 3, Eval
#
#
# Accuracy: SVC-0.1-3; 0.5616
#
# Elapsed time: 0.53s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 0.1, degree: 4, Eval
#
#
# Accuracy: SVC-0.1-4; 0.5616
#
# Elapsed time: 0.53s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 0.1, degree: 5, Eval
#
#
# Accuracy: SVC-0.1-5; 0.5622
#
# Elapsed time: 0.54s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 1, degree: 2, Eval
#
#
# Accuracy: SVC-1-2; 0.7926
#
# Elapsed time: 0.52s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 1, degree: 3, Eval
#
#
# Accuracy: SVC-1-3; 0.6998
#
# Elapsed time: 0.53s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 1, degree: 4, Eval
#
#
# Accuracy: SVC-1-4; 0.6287
#
# Elapsed time: 0.52s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 1, degree: 5, Eval
#
#
# Accuracy: SVC-1-5; 0.5991
#
# Elapsed time: 0.5s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 10, degree: 2, Eval
#
#
# Accuracy: SVC-10-2; 0.7900
#
# Elapsed time: 0.47s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 10, degree: 3, Eval
#
#
# Accuracy: SVC-10-3; 0.7828
#
# Elapsed time: 0.49s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 10, degree: 4, Eval
#
#
# Accuracy: SVC-10-4; 0.7499
#
# Elapsed time: 0.5s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 10, degree: 5, Eval
#
#
# Accuracy: SVC-10-5; 0.7011
#
# Elapsed time: 0.5s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 100, degree: 2, Eval
#
#
# Accuracy: SVC-100-2; 0.7814
#
# Elapsed time: 0.48s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 100, degree: 3, Eval
#
#
# Accuracy: SVC-100-3; 0.7749
#
# Elapsed time: 0.49s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 100, degree: 4, Eval
#
#
# Accuracy: SVC-100-4; 0.7788
#
# Elapsed time: 0.5s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 100, degree: 5, Eval
#
#
# Accuracy: SVC-100-5; 0.7472
#
# Elapsed time: 0.51s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 1000, degree: 2, Eval
#
#
# Accuracy: SVC-1000-2; 0.7749
#
# Elapsed time: 0.46s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 1000, degree: 3, Eval
#
#
# Accuracy: SVC-1000-3; 0.7656
#
# Elapsed time: 0.48s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 1000, degree: 4, Eval
#
#
# Accuracy: SVC-1000-4; 0.7512
#
# Elapsed time: 0.49s
#
#
# Regression: False, Fingerprint: True, PCA: False
# C: 1000, degree: 5, Eval
#
#
# Accuracy: SVC-1000-5; 0.7492
#
# Elapsed time: 0.51s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 2, Eval
#
#
# Accuracy: SVC-0.01-2; 0.5609
#
# Elapsed time: 0.2s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 3, Eval
#
#
# Accuracy: SVC-0.01-3; 0.5609
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 4, Eval
#
#
# Accuracy: SVC-0.01-4; 0.5609
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 5, Eval
#
#
# Accuracy: SVC-0.01-5; 0.5609
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 2, Eval
#
#
# Accuracy: SVC-0.1-2; 0.5609
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 3, Eval
#
#
# Accuracy: SVC-0.1-3; 0.5616
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 4, Eval
#
#
# Accuracy: SVC-0.1-4; 0.5616
#
# Elapsed time: 0.2s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 5, Eval
#
#
# Accuracy: SVC-0.1-5; 0.5635
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1, degree: 2, Eval
#
#
# Accuracy: SVC-1-2; 0.7972
#
# Elapsed time: 0.18s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1, degree: 3, Eval
#
#
# Accuracy: SVC-1-3; 0.7070
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1, degree: 4, Eval
#
#
# Accuracy: SVC-1-4; 0.6392
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1, degree: 5, Eval
#
#
# Accuracy: SVC-1-5; 0.6076
#
# Elapsed time: 0.2s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 10, degree: 2, Eval
#
#
# Accuracy: SVC-10-2; 0.7907
#
# Elapsed time: 0.18s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 10, degree: 3, Eval
#
#
# Accuracy: SVC-10-3; 0.7828
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 10, degree: 4, Eval
#
#
# Accuracy: SVC-10-4; 0.7518
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 10, degree: 5, Eval
#
#
# Accuracy: SVC-10-5; 0.7084
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 100, degree: 2, Eval
#
#
# Accuracy: SVC-100-2; 0.7716
#
# Elapsed time: 0.17s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 100, degree: 3, Eval
#
#
# Accuracy: SVC-100-3; 0.7729
#
# Elapsed time: 0.18s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 100, degree: 4, Eval
#
#
# Accuracy: SVC-100-4; 0.7729
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 100, degree: 5, Eval
#
#
# Accuracy: SVC-100-5; 0.7485
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1000, degree: 2, Eval
#
#
# Accuracy: SVC-1000-2; 0.7670
#
# Elapsed time: 0.17s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1000, degree: 3, Eval
#
#
# Accuracy: SVC-1000-3; 0.7703
#
# Elapsed time: 0.18s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1000, degree: 4, Eval
#
#
# Accuracy: SVC-1000-4; 0.7577
#
# Elapsed time: 0.19s
#
#
# Regression: False, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1000, degree: 5, Eval
#
#
# Accuracy: SVC-1000-5; 0.7676
#
# Elapsed time: 0.19s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 0.01, degree: 2, Eval
#
#
# Accuracy: SVR-0.01-2; -1.7038
#
# Elapsed time: 0.29s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 0.01, degree: 3, Eval
#
#
# Accuracy: SVR-0.01-3; -1.8045
#
# Elapsed time: 0.3s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 0.01, degree: 4, Eval
#
#
# Accuracy: SVR-0.01-4; -2.5515
#
# Elapsed time: 0.3s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 0.01, degree: 5, Eval
#
#
# Accuracy: SVR-0.01-5; -20.5296
#
# Elapsed time: 0.31s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 0.1, degree: 2, Eval
#
#
# Accuracy: SVR-0.1-2; -1.2466
#
# Elapsed time: 0.3s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 0.1, degree: 3, Eval
#
#
# Accuracy: SVR-0.1-3; -1.6455
#
# Elapsed time: 0.3s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 0.1, degree: 4, Eval
#
#
# Accuracy: SVR-0.1-4; -10.6130
#
# Elapsed time: 0.3s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 0.1, degree: 5, Eval
#
#
# Accuracy: SVR-0.1-5; -48.9506
#
# Elapsed time: 0.3s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 1, degree: 2, Eval
#
#
# Accuracy: SVR-1-2; -0.9552
#
# Elapsed time: 0.29s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 1, degree: 3, Eval
#
#
# Accuracy: SVR-1-3; -1.6164
#
# Elapsed time: 0.29s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 1, degree: 4, Eval
#
#
# Accuracy: SVR-1-4; -25.4547
#
# Elapsed time: 0.3s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 1, degree: 5, Eval
#
#
# Accuracy: SVR-1-5; -16.4434
#
# Elapsed time: 0.3s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 10, degree: 2, Eval
#
#
# Accuracy: SVR-10-2; -1.4629
#
# Elapsed time: 0.33s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 10, degree: 3, Eval
#
#
# Accuracy: SVR-10-3; -2.1094
#
# Elapsed time: 0.31s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 10, degree: 4, Eval
#
#
# Accuracy: SVR-10-4; -7.3191
#
# Elapsed time: 0.31s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 10, degree: 5, Eval
#
#
# Accuracy: SVR-10-5; -161.6741
#
# Elapsed time: 0.31s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 100, degree: 2, Eval
#
#
# Accuracy: SVR-100-2; -1.6870
#
# Elapsed time: 0.43s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 100, degree: 3, Eval
#
#
# Accuracy: SVR-100-3; -1.9429
#
# Elapsed time: 0.35s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 100, degree: 4, Eval
#
#
# Accuracy: SVR-100-4; -2.9383
#
# Elapsed time: 0.33s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 100, degree: 5, Eval
#
#
# Accuracy: SVR-100-5; -410.5389
#
# Elapsed time: 0.33s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 1000, degree: 2, Eval
#
#
# Accuracy: SVR-1000-2; -1.6697
#
# Elapsed time: 0.45s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 1000, degree: 3, Eval
#
#
# Accuracy: SVR-1000-3; -1.9870
#
# Elapsed time: 0.36s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 1000, degree: 4, Eval
#
#
# Accuracy: SVR-1000-4; -2.9572
#
# Elapsed time: 0.33s
#
#
# Regression: True, Fingerprint: False, PCA: False
# C: 1000, degree: 5, Eval
#
#
# Accuracy: SVR-1000-5; -468.3448
#
# Elapsed time: 0.33s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 2, Eval
#
#
# Accuracy: SVR-0.01-2; -1.6907
#
# Elapsed time: 0.06s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 3, Eval
#
#
# Accuracy: SVR-0.01-3; -1.7812
#
# Elapsed time: 0.06s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 4, Eval
#
#
# Accuracy: SVR-0.01-4; -2.9892
#
# Elapsed time: 0.06s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 5, Eval
#
#
# Accuracy: SVR-0.01-5; -13.3042
#
# Elapsed time: 0.06s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 2, Eval
#
#
# Accuracy: SVR-0.1-2; -1.2630
#
# Elapsed time: 0.06s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 3, Eval
#
#
# Accuracy: SVR-0.1-3; -1.4661
#
# Elapsed time: 0.06s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 4, Eval
#
#
# Accuracy: SVR-0.1-4; -14.3375
#
# Elapsed time: 0.06s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 5, Eval
#
#
# Accuracy: SVR-0.1-5; -21.1224
#
# Elapsed time: 0.06s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1, degree: 2, Eval
#
#
# Accuracy: SVR-1-2; -1.1799
#
# Elapsed time: 0.06s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1, degree: 3, Eval
#
#
# Accuracy: SVR-1-3; -1.3294
#
# Elapsed time: 0.07s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1, degree: 4, Eval
#
#
# Accuracy: SVR-1-4; -34.3333
#
# Elapsed time: 0.07s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1, degree: 5, Eval
#
#
# Accuracy: SVR-1-5; -19.5687
#
# Elapsed time: 0.07s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 10, degree: 2, Eval
#
#
# Accuracy: SVR-10-2; -2.3979
#
# Elapsed time: 0.11s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 10, degree: 3, Eval
#
#
# Accuracy: SVR-10-3; -1.5834
#
# Elapsed time: 0.11s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 10, degree: 4, Eval
#
#
# Accuracy: SVR-10-4; -2.6234
#
# Elapsed time: 0.1s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 10, degree: 5, Eval
#
#
# Accuracy: SVR-10-5; -1657.4749
#
# Elapsed time: 0.1s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 100, degree: 2, Eval
#
#
# Accuracy: SVR-100-2; -2.9643
#
# Elapsed time: 0.57s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 100, degree: 3, Eval
#
#
# Accuracy: SVR-100-3; -11.5547
#
# Elapsed time: 0.19s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 100, degree: 4, Eval
#
#
# Accuracy: SVR-100-4; -150.4415
#
# Elapsed time: 0.13s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 100, degree: 5, Eval
#
#
# Accuracy: SVR-100-5; -4121.0386
#
# Elapsed time: 0.13s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1000, degree: 2, Eval
#
#
# Accuracy: SVR-1000-2; -4.3891
#
# Elapsed time: 1.38s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1000, degree: 3, Eval
#
#
# Accuracy: SVR-1000-3; -14.9259
#
# Elapsed time: 0.21s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1000, degree: 4, Eval
#
#
# Accuracy: SVR-1000-4; -211.4917
#
# Elapsed time: 0.15s
#
#
# Regression: True, Fingerprint: False, PCA: PCA(n_components=0.95)
# C: 1000, degree: 5, Eval
#
#
# Accuracy: SVR-1000-5; -5813.3302
#
# Elapsed time: 0.15s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 0.01, degree: 2, Eval
#
#
# Accuracy: SVR-0.01-2; -1.8576
#
# Elapsed time: 0.46s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 0.01, degree: 3, Eval
#
#
# Accuracy: SVR-0.01-3; -1.8673
#
# Elapsed time: 0.47s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 0.01, degree: 4, Eval
#
#
# Accuracy: SVR-0.01-4; -1.8683
#
# Elapsed time: 0.51s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 0.01, degree: 5, Eval
#
#
# Accuracy: SVR-0.01-5; -1.8663
#
# Elapsed time: 0.47s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 0.1, degree: 2, Eval
#
#
# Accuracy: SVR-0.1-2; -1.6518
#
# Elapsed time: 0.46s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 0.1, degree: 3, Eval
#
#
# Accuracy: SVR-0.1-3; -1.7431
#
# Elapsed time: 0.46s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 0.1, degree: 4, Eval
#
#
# Accuracy: SVR-0.1-4; -1.7784
#
# Elapsed time: 0.47s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 0.1, degree: 5, Eval
#
#
# Accuracy: SVR-0.1-5; -1.7986
#
# Elapsed time: 0.47s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 1, degree: 2, Eval
#
#
# Accuracy: SVR-1-2; -0.9566
#
# Elapsed time: 0.47s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 1, degree: 3, Eval
#
#
# Accuracy: SVR-1-3; -1.2958
#
# Elapsed time: 0.46s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 1, degree: 4, Eval
#
#
# Accuracy: SVR-1-4; -1.5084
#
# Elapsed time: 0.47s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 1, degree: 5, Eval
#
#
# Accuracy: SVR-1-5; -1.6359
#
# Elapsed time: 0.47s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 10, degree: 2, Eval
#
#
# Accuracy: SVR-10-2; -0.7820
#
# Elapsed time: 0.45s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 10, degree: 3, Eval
#
#
# Accuracy: SVR-10-3; -0.9680
#
# Elapsed time: 0.46s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 10, degree: 4, Eval
#
#
# Accuracy: SVR-10-4; -1.1785
#
# Elapsed time: 0.49s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 10, degree: 5, Eval
#
#
# Accuracy: SVR-10-5; -1.3814
#
# Elapsed time: 0.48s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 100, degree: 2, Eval
#
#
# Accuracy: SVR-100-2; -0.7636
#
# Elapsed time: 0.46s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 100, degree: 3, Eval
#
#
# Accuracy: SVR-100-3; -0.9211
#
# Elapsed time: 0.48s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 100, degree: 4, Eval
#
#
# Accuracy: SVR-100-4; -1.0534
#
# Elapsed time: 0.51s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 100, degree: 5, Eval
#
#
# Accuracy: SVR-100-5; -1.1801
#
# Elapsed time: 0.5s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 1000, degree: 2, Eval
#
#
# Accuracy: SVR-1000-2; -0.7629
#
# Elapsed time: 0.46s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 1000, degree: 3, Eval
#
#
# Accuracy: SVR-1000-3; -0.8945
#
# Elapsed time: 0.47s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 1000, degree: 4, Eval
#
#
# Accuracy: SVR-1000-4; -1.0210
#
# Elapsed time: 0.47s
#
#
# Regression: True, Fingerprint: True, PCA: False
# C: 1000, degree: 5, Eval
#
#
# Accuracy: SVR-1000-5; -1.1419
#
# Elapsed time: 0.47s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 2, Eval
#
#
# Accuracy: SVR-0.01-2; -1.8544
#
# Elapsed time: 0.18s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 3, Eval
#
#
# Accuracy: SVR-0.01-3; -1.8637
#
# Elapsed time: 0.18s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 4, Eval
#
#
# Accuracy: SVR-0.01-4; -1.8651
#
# Elapsed time: 0.19s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.01, degree: 5, Eval
#
#
# Accuracy: SVR-0.01-5; -1.8592
#
# Elapsed time: 0.19s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 2, Eval
#
#
# Accuracy: SVR-0.1-2; -1.6273
#
# Elapsed time: 0.18s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 3, Eval
#
#
# Accuracy: SVR-0.1-3; -1.7210
#
# Elapsed time: 0.19s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 4, Eval
#
#
# Accuracy: SVR-0.1-4; -1.7590
#
# Elapsed time: 0.19s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 0.1, degree: 5, Eval
#
#
# Accuracy: SVR-0.1-5; -1.7796
#
# Elapsed time: 0.19s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1, degree: 2, Eval
#
#
# Accuracy: SVR-1-2; -0.9264
#
# Elapsed time: 0.19s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1, degree: 3, Eval
#
#
# Accuracy: SVR-1-3; -1.2463
#
# Elapsed time: 0.19s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1, degree: 4, Eval
#
#
# Accuracy: SVR-1-4; -1.4600
#
# Elapsed time: 0.19s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1, degree: 5, Eval
#
#
# Accuracy: SVR-1-5; -1.5947
#
# Elapsed time: 0.19s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 10, degree: 2, Eval
#
#
# Accuracy: SVR-10-2; -0.7805
#
# Elapsed time: 0.19s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 10, degree: 3, Eval
#
#
# Accuracy: SVR-10-3; -0.9427
#
# Elapsed time: 0.21s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 10, degree: 4, Eval
#
#
# Accuracy: SVR-10-4; -1.1310
#
# Elapsed time: 0.2s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 10, degree: 5, Eval
#
#
# Accuracy: SVR-10-5; -1.3213
#
# Elapsed time: 0.2s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 100, degree: 2, Eval
#
#
# Accuracy: SVR-100-2; -0.7861
#
# Elapsed time: 0.2s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 100, degree: 3, Eval
#
#
# Accuracy: SVR-100-3; -0.9030
#
# Elapsed time: 0.2s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 100, degree: 4, Eval
#
#
# Accuracy: SVR-100-4; -1.0119
#
# Elapsed time: 0.2s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 100, degree: 5, Eval
#
#
# Accuracy: SVR-100-5; -1.1254
#
# Elapsed time: 0.2s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1000, degree: 2, Eval
#
#
# Accuracy: SVR-1000-2; -0.7941
#
# Elapsed time: 0.19s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1000, degree: 3, Eval
#
#
# Accuracy: SVR-1000-3; -0.8868
#
# Elapsed time: 0.21s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1000, degree: 4, Eval
#
#
# Accuracy: SVR-1000-4; -0.9976
#
# Elapsed time: 0.2s
#
#
# Regression: True, Fingerprint: True, PCA: PCA(n_components=0.95)
# C: 1000, degree: 5, Eval
#
#
# Accuracy: SVR-1000-5; -1.1088
#
# Elapsed time: 0.2s

# %%
for key, run in result_dict.items():
    print(key)
    for test in run:
        print(test)
    print()
# Out:
# results_classification_descriptors_sc_svm.csv
# SVC-0.01-2; 0.5616
# SVC-0.01-3; 0.5648
# SVC-0.01-4; 0.5708
# SVC-0.01-5; 0.5734
# SVC-0.1-2; 0.6287
# SVC-0.1-3; 0.6484
# SVC-0.1-4; 0.5951
# SVC-0.1-5; 0.5971
# SVC-1-2; 0.7689
# SVC-1-3; 0.7913
# SVC-1-4; 0.7511
# SVC-1-5; 0.7288
# SVC-10-2; 0.7834
# SVC-10-3; 0.7979
# SVC-10-4; 0.7854
# SVC-10-5; 0.7828
# SVC-100-2; 0.7683
# SVC-100-3; 0.7788
# SVC-100-4; 0.7939
# SVC-100-5; 0.7893
# SVC-1000-2; 0.7637
# SVC-1000-3; 0.7696
# SVC-1000-4; 0.7775
# SVC-1000-5; 0.7729
#
# results_classification_descriptors_scpca_svm.csv
# SVC-0.01-2; 0.5616
# SVC-0.01-3; 0.5675
# SVC-0.01-4; 0.5714
# SVC-0.01-5; 0.5747
# SVC-0.1-2; 0.6340
# SVC-0.1-3; 0.6557
# SVC-0.1-4; 0.5997
# SVC-0.1-5; 0.6004
# SVC-1-2; 0.7617
# SVC-1-3; 0.7900
# SVC-1-4; 0.7571
# SVC-1-5; 0.7367
# SVC-10-2; 0.7749
# SVC-10-3; 0.7992
# SVC-10-4; 0.7907
# SVC-10-5; 0.7887
# SVC-100-2; 0.7597
# SVC-100-3; 0.7788
# SVC-100-4; 0.7861
# SVC-100-5; 0.7814
# SVC-1000-2; 0.7406
# SVC-1000-3; 0.7485
# SVC-1000-4; 0.7709
# SVC-1000-5; 0.7676
#
# results_classification_fingerprints_sc_svm.csv
# SVC-0.01-2; 0.5609
# SVC-0.01-3; 0.5609
# SVC-0.01-4; 0.5609
# SVC-0.01-5; 0.5609
# SVC-0.1-2; 0.5609
# SVC-0.1-3; 0.5616
# SVC-0.1-4; 0.5616
# SVC-0.1-5; 0.5622
# SVC-1-2; 0.7926
# SVC-1-3; 0.6998
# SVC-1-4; 0.6287
# SVC-1-5; 0.5991
# SVC-10-2; 0.7900
# SVC-10-3; 0.7828
# SVC-10-4; 0.7499
# SVC-10-5; 0.7011
# SVC-100-2; 0.7814
# SVC-100-3; 0.7749
# SVC-100-4; 0.7788
# SVC-100-5; 0.7472
# SVC-1000-2; 0.7749
# SVC-1000-3; 0.7656
# SVC-1000-4; 0.7512
# SVC-1000-5; 0.7492
#
# results_classification_fingerprints_scpca_svm.csv
# SVC-0.01-2; 0.5609
# SVC-0.01-3; 0.5609
# SVC-0.01-4; 0.5609
# SVC-0.01-5; 0.5609
# SVC-0.1-2; 0.5609
# SVC-0.1-3; 0.5616
# SVC-0.1-4; 0.5616
# SVC-0.1-5; 0.5635
# SVC-1-2; 0.7972
# SVC-1-3; 0.7070
# SVC-1-4; 0.6392
# SVC-1-5; 0.6076
# SVC-10-2; 0.7907
# SVC-10-3; 0.7828
# SVC-10-4; 0.7518
# SVC-10-5; 0.7084
# SVC-100-2; 0.7716
# SVC-100-3; 0.7729
# SVC-100-4; 0.7729
# SVC-100-5; 0.7485
# SVC-1000-2; 0.7670
# SVC-1000-3; 0.7703
# SVC-1000-4; 0.7577
# SVC-1000-5; 0.7676
#
# results_regression_descriptors_sc_svm.csv
# SVR-0.01-2; -1.7038
# SVR-0.01-3; -1.8045
# SVR-0.01-4; -2.5515
# SVR-0.01-5; -20.5296
# SVR-0.1-2; -1.2466
# SVR-0.1-3; -1.6455
# SVR-0.1-4; -10.6130
# SVR-0.1-5; -48.9506
# SVR-1-2; -0.9552
# SVR-1-3; -1.6164
# SVR-1-4; -25.4547
# SVR-1-5; -16.4434
# SVR-10-2; -1.4629
# SVR-10-3; -2.1094
# SVR-10-4; -7.3191
# SVR-10-5; -161.6741
# SVR-100-2; -1.6870
# SVR-100-3; -1.9429
# SVR-100-4; -2.9383
# SVR-100-5; -410.5389
# SVR-1000-2; -1.6697
# SVR-1000-3; -1.9870
# SVR-1000-4; -2.9572
# SVR-1000-5; -468.3448
#
# results_regression_descriptors_scpca_svm.csv
# SVR-0.01-2; -1.6907
# SVR-0.01-3; -1.7812
# SVR-0.01-4; -2.9892
# SVR-0.01-5; -13.3042
# SVR-0.1-2; -1.2630
# SVR-0.1-3; -1.4661
# SVR-0.1-4; -14.3375
# SVR-0.1-5; -21.1224
# SVR-1-2; -1.1799
# SVR-1-3; -1.3294
# SVR-1-4; -34.3333
# SVR-1-5; -19.5687
# SVR-10-2; -2.3979
# SVR-10-3; -1.5834
# SVR-10-4; -2.6234
# SVR-10-5; -1657.4749
# SVR-100-2; -2.9643
# SVR-100-3; -11.5547
# SVR-100-4; -150.4415
# SVR-100-5; -4121.0386
# SVR-1000-2; -4.3891
# SVR-1000-3; -14.9259
# SVR-1000-4; -211.4917
# SVR-1000-5; -5813.3302
#
# results_regression_fingerprints_sc_svm.csv
# SVR-0.01-2; -1.8576
# SVR-0.01-3; -1.8673
# SVR-0.01-4; -1.8683
# SVR-0.01-5; -1.8663
# SVR-0.1-2; -1.6518
# SVR-0.1-3; -1.7431
# SVR-0.1-4; -1.7784
# SVR-0.1-5; -1.7986
# SVR-1-2; -0.9566
# SVR-1-3; -1.2958
# SVR-1-4; -1.5084
# SVR-1-5; -1.6359
# SVR-10-2; -0.7820
# SVR-10-3; -0.9680
# SVR-10-4; -1.1785
# SVR-10-5; -1.3814
# SVR-100-2; -0.7636
# SVR-100-3; -0.9211
# SVR-100-4; -1.0534
# SVR-100-5; -1.1801
# SVR-1000-2; -0.7629
# SVR-1000-3; -0.8945
# SVR-1000-4; -1.0210
# SVR-1000-5; -1.1419
#
# results_regression_fingerprints_scpca_svm.csv
# SVR-0.01-2; -1.8544
# SVR-0.01-3; -1.8637
# SVR-0.01-4; -1.8651
# SVR-0.01-5; -1.8592
# SVR-0.1-2; -1.6273
# SVR-0.1-3; -1.7210
# SVR-0.1-4; -1.7590
# SVR-0.1-5; -1.7796
# SVR-1-2; -0.9264
# SVR-1-3; -1.2463
# SVR-1-4; -1.4600
# SVR-1-5; -1.5947
# SVR-10-2; -0.7805
# SVR-10-3; -0.9427
# SVR-10-4; -1.1310
# SVR-10-5; -1.3213
# SVR-100-2; -0.7861
# SVR-100-3; -0.9030
# SVR-100-4; -1.0119
# SVR-100-5; -1.1254
# SVR-1000-2; -0.7941
# SVR-1000-3; -0.8868
# SVR-1000-4; -0.9976
# SVR-1000-5; -1.1088
