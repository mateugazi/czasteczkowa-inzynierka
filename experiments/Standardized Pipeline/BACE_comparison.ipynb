# %%
import warnings
from itertools import product

import os
import numpy as np
import pandas as pd
from mordred import Calculator, descriptors
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.decomposition import PCA
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import (StratifiedKFold, KFold,
                                     cross_val_score, train_test_split)

from sklearn.metrics import r2_score
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.svm import SVC

warnings.filterwarnings("ignore", category=Warning)

N_SPLITS = 2
RANDOM_STATE = 148260

use_descriptors = True
use_fingerprints = False

# %% [markdown]
# ### Preprocessing

# %%
def LoadCSV(path):
    df = pd.read_csv(path)
    return df

def LoadCSV_BACE(path, regression = False):
    df = pd.read_csv(path)
    df.drop_duplicates('mol')
    df = df.dropna()
    df.drop(['CID', 'canvasUID'], axis=1, inplace=True)
    if regression:
        df['Target'] = df['pIC50']
        df.drop('Class', axis=1, inplace=True)
        df.drop('pIC50', axis=1, inplace=True)
    else:
        df['Target'] = df['Class']
        df.drop('Class', axis=1, inplace=True)
        df.drop('pIC50', axis=1, inplace=True)
    return df

def split_data_BACE(df, scaffold=True):
    X = df.drop(['Target', 'mol'], axis=1)

    if not scaffold:
        y = df[['Target']]
        X = X.drop(['Model'], axis=1)

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
        X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.111, random_state=42)
        return X_train, y_train, X_test, y_test, X_valid, y_valid

    #dummy = list(X['Model'])
    #
    #sc = StandardScaler()
    #X = sc.fit_transform(X.drop(['Model'], axis=1))
    #X = pd.DataFrame(X)
    #
    #X['Model'] = dummy

    X_train = X[X['Model'] == 'Train']
    X_test = X[X['Model'] == 'Test']
    X_valid = X[X['Model'] == 'Valid']

    y = df[['Target', 'Model']]

    y_train = y[y['Model'] == 'Train']
    y_test = y[y['Model'] == 'Test']
    y_valid = y[y['Model'] == 'Valid']
    
    X_train.drop('Model', axis=1, inplace=True)
    X_test.drop('Model', axis=1, inplace=True)
    X_valid.drop('Model', axis=1, inplace=True)
    y_train.drop('Model', axis=1, inplace=True)
    y_test.drop('Model', axis=1, inplace=True)
    y_valid.drop('Model', axis=1, inplace=True)
    
    return X_train, y_train, X_test, y_test, X_valid, y_valid
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 def LoadCSV(path):
#       2     df = pd.read_csv(path)
#       3     return df
#
# Cell In[112], line 1
# ----> 1 def LoadCSV(path):
#       2     df = pd.read_csv(path)
#       3     return df
#
# File _pydevd_bundle/pydevd_cython.pyx:1457, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython.pyx:701, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1152, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1135, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:312, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\debugpy\_vendored\pydevd\pydevd.py:2070, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2067             from_this_thread.append(frame_custom_thread_id)
#    2069     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2070         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2072 frames_list = None
#    2074 if keep_suspended:
#    2075     # This means that we should pause again after a set next statement.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\debugpy\_vendored\pydevd\pydevd.py:2106, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2103         self._call_input_hook()
#    2105     self.process_internal_commands()
# -> 2106     time.sleep(0.01)
#    2108 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    2110 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
def Load_downloaded_CSV(path, regression = False, calculate_pIC50 = False):
    df = pd.read_csv(path)
    
    ### Replace with standardizing molecules and then dropping duplicates
    #df.drop_duplicates('mol')
    #df = df.dropna()
    
    if 'target' in df.columns:
        df['Target'] = df['target']
        df.drop('target', axis=1, inplace=True)
        
    if regression:
        if 'IC50' in df.columns:
            calculate_pIC50 = True
            df['Target'] = df['IC50']
            df.drop('IC50', axis=1, inplace=True)
        if 'pIC50' in df.columns:
            df['Target'] = df['pIC50']
            df.drop('pIC50', axis=1, inplace=True)
    else:
        if 'Class' in df.columns:
            df['Target'] = df['Class']
            df.drop('Class', axis=1, inplace=True)
        
    if 'SMILES' in df.columns:
        df['mol'] = df['SMILES']
        df.drop('SMILES', axis=1, inplace=True)
    
    if calculate_pIC50:
        df['Target'] = [-np.log10(i * 10**(-9)) for i in list(df['Target'])]
        if not regression:
            df['Target'] = [int(i > 7) for i in list(df['Target'])]

    df = df[['mol', 'Target']]

    if use_descriptors:
        new_df = CalculateDescriptors(df['mol'])
    if use_fingerprints:
        new_df = CalculateMorganFingerprint(df['mol'])
        
    new_df['Target'] = df['Target']

    return new_df

def Split_downloaded_CSV(df):
    X = df.drop(['Target'], axis=1)
    y = df[['Target']]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.111, random_state=42)
    return X_train, y_train, X_test, y_test, X_valid, y_valid

# %%
dir_path = os.path.join(os.path.dirname(os.getcwd()), "BACE", "bace.csv")
print(dir_path)

df_regression = LoadCSV_BACE(dir_path, regression=True)
df_classification = LoadCSV_BACE(dir_path)
# Out:
# c:\Users\admin\Documents\GitHub\czasteczkowa-inzynierka\experiments\BACE\bace.csv

# %%
scaffold = False

# %%
X_train_class, y_train_class, X_test_class, y_test_class, X_valid_class, y_valid_class = split_data_BACE(df_classification, scaffold=scaffold)

# %%
X_train_regre, y_train_regre, X_test_regre, y_test_regre, X_valid_regre, y_valid_regre = split_data_BACE(df_regression, scaffold=scaffold)

# %%
df_classification.head()
# Out:
#                                                  mol  Model         MW  \
# 0  O1CC[C@@H](NC(=O)[C@@H](Cc2cc3cc(ccc3nc2N)-c2c...  Train  431.56979
# 1  Fc1cc(cc(F)c1)C[C@H](NC(=O)[C@@H](N1CC[C@](NC(...  Train  657.81073
# 2  S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...  Train  591.74091
# 3  S1(=O)(=O)C[C@@H](Cc2cc(O[C@H](COCC)C(F)(F)F)c...  Train  591.67828
# 4  S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...  Train  629.71283
#
#     AlogP  HBA  HBD  RB  HeavyAtomCount  ChiralCenterCount  \
# 0  4.4014    3    2   5              32                  2
# 1  2.6412    5    4  16              47                  6
# 2  2.5499    4    3  11              42                  2
# 3  3.1680    4    3  12              40                  4
# 4  3.5086    3    3  11              44                  2
#
#    ChiralCenterCountAllPossible  ...  PEOE6 (PEOE6)  PEOE7 (PEOE7)  \
# 0                             2  ...      53.205711      78.640335
# 1                             6  ...      73.817162      47.171600
# 2                             3  ...      70.365707      47.941147
# 3                             5  ...      56.657166      37.954151
# 4                             3  ...      78.945702      39.361153
#
#    PEOE8 (PEOE8)  PEOE9 (PEOE9)  PEOE10 (PEOE10)  PEOE11 (PEOE11)  \
# 0      226.85541      107.43491        37.133846         0.000000
# 1      365.67694      174.07675        34.923889         7.980170
# 2      192.40652      255.75255        23.654478         0.230159
# 3      194.35304      202.76335        36.498634         0.980913
# 4      179.71288      220.46130        23.654478         0.230159
#
#    PEOE12 (PEOE12)  PEOE13 (PEOE13)  PEOE14 (PEOE14)  Target
# 0         7.980170              0.0         0.000000       1
# 1        24.148668              0.0        24.663788       1
# 2        15.879790              0.0        24.663788       1
# 3         8.188327              0.0        26.385181       1
# 4        15.879790              0.0        26.100143       1
#
# [5 rows x 592 columns]

# %%
y_train_regre
# Out:
#         Target
# 1435  4.356547
# 1153  5.769551
# 918   6.580000
# 1191  5.638272
# 521   7.585027
# ...        ...
# 152   5.494850
# 1497  3.488117
# 34    7.920819
# 383   8.000000
# 262   8.698970
#
# [1209 rows x 1 columns]

# %%
print(X_train_class.shape)
print(X_test_class.shape)
print(X_valid_class.shape)
print(f"{round(X_train_class.shape[0] / df_classification.shape[0], 2)}")
print(f"{round(X_test_class.shape[0] / df_classification.shape[0], 2)}")
print(f"{round(X_valid_class.shape[0] / df_classification.shape[0], 2)}")
# Out:
# (1209, 589)
# (152, 589)
# (152, 589)
# 0.8
# 0.1
# 0.1

# %%
df_classification.describe()
# Out:
#                 MW        AlogP          HBA          HBD           RB  \
# count  1513.000000  1513.000000  1513.000000  1513.000000  1513.000000
# mean    479.661988     3.177080     3.732981     2.001322     8.049570
# std     122.083053     1.396633     1.444778     1.629343     4.741135
# min     138.187000    -4.361100     0.000000     0.000000     0.000000
# 25%     389.331300     2.335500     3.000000     0.000000     4.000000
# 50%     463.628300     3.171300     4.000000     2.000000     7.000000
# 75%     564.639530     4.015500     4.000000     3.000000    11.000000
# max    1350.473300     7.617400    12.000000    15.000000    40.000000
#
#        HeavyAtomCount  ChiralCenterCount  ChiralCenterCountAllPossible  \
# count     1513.000000        1513.000000                   1513.000000
# mean        34.089227           0.522802                      2.317250
# std          8.520088           1.162539                      1.612558
# min         10.000000           0.000000                      0.000000
# 25%         28.000000           0.000000                      1.000000
# 50%         33.000000           0.000000                      2.000000
# 75%         40.000000           1.000000                      3.000000
# max         97.000000          10.000000                     12.000000
#
#          RingCount          PSA  ...  PEOE6 (PEOE6)  PEOE7 (PEOE7)  \
# count  1513.000000  1513.000000  ...    1513.000000    1513.000000
# mean      3.769993    99.842829  ...      52.348846      48.763740
# std       0.877390    34.973718  ...      25.993800      18.201519
# min       0.000000    16.610001  ...       0.000000      -3.551821
# 25%       3.000000    77.050003  ...      34.319988      36.547150
# 50%       4.000000    95.040001  ...      51.479984      47.624382
# 75%       4.000000   116.630000  ...      66.553795      58.844093
# max       7.000000   525.060000  ...     161.342860     124.272730
#
#        PEOE8 (PEOE8)  PEOE9 (PEOE9)  PEOE10 (PEOE10)  PEOE11 (PEOE11)  \
# count    1513.000000    1513.000000      1513.000000      1513.000000
# mean      181.835580     148.442348        30.371697         3.488650
# std        99.717702      60.548833        12.162452         5.148336
# min         1.916970      -5.536391        -2.216191        -7.286308
# 25%       102.233770     102.510450        20.132990         0.000000
# 50%       171.917220     140.683620        30.107586         0.550130
# 75%       253.679080     185.659260        37.133846         7.980170
# max       865.473330     378.516270       121.671900        29.823961
#
#        PEOE12 (PEOE12)  PEOE13 (PEOE13)  PEOE14 (PEOE14)       Target
# count      1513.000000      1513.000000      1513.000000  1513.000000
# mean         11.740560         1.239762        14.387597     0.456709
# std           9.073406         3.293804        13.329890     0.498287
# min          -6.106466        -7.379991        -1.273524     0.000000
# 25%           7.980170         0.000000         0.000000     0.000000
# 50%           8.188327         0.000000        21.710098     0.000000
# 75%          15.879790         0.000000        24.663788     1.000000
# max          80.218018        16.681131        61.659470     1.000000
#
# [8 rows x 590 columns]

# %% [markdown]
# ### Run configurations

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score
def results_metrics(y_true, y_pred, regression=False):
    if regression:
        mae = mean_absolute_error(y_true, y_pred)
        rmse = mean_squared_error(y_true, y_pred, squared=False)
        mse = mean_squared_error(y_true, y_pred)
        r2 = r2_score(y_true, y_pred)
        return [mae, rmse, mse, r2]
    else:
        accuracy = accuracy_score(y_true, y_pred)
        roc_auc = roc_auc_score(y_true, y_pred)
        precision = precision_score(y_true, y_pred)
        recall = recall_score(y_true, y_pred)
        f1 = f1_score(y_true, y_pred)
        return [accuracy, roc_auc, precision, recall, f1]

# %%
def run_rf(X_train, X_test, X_valid, y_train, y_test, y_valid, n_estimators, max_depth, min_samples_split, min_samples_leaf, regression=False):
    
    if regression:
        name = "RandomForestRegressor"
        model = RandomForestRegressor(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf)
    else:
        name = "RandomForestClassifier"
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf)
        
    model.fit(X_train, y_train)
    y_predicted = model.predict(X_test)
    results = results_metrics(y_test, y_predicted, regression)

    output_str = f"Model: {name}-{n_estimators}-{max_depth}-{min_samples_split}-{min_samples_leaf} | "
    if regression: output_str += f"MAE: {results[0]} | RMSE: {results[1]} | MSE: {results[2]} | R2: {results[3]}"
    else: output_str += f"Accuracy: {results[0]} | ROC-AUC: {results[1]} | Precision: {results[2]} | Recall: {results[3]} | F1: {results[4]}"
    return (output_str)

def run_lr(X_train, X_test, X_valid, y_train, y_test, y_valid, C, penalty, solver, regression=False):
    if regression:
        name = "LinearRegression"
        model = LinearRegression()
    else:
        name = "LogisticRegression"
        model = LogisticRegression(C=C, penalty=penalty, solver=solver)
        
    model.fit(X_train, y_train)
    y_predicted = model.predict(X_test)
    results = results_metrics(y_test, y_predicted, regression)

    output_str = f"Model: {name}-{C}-{penalty}-{solver} | "
    if regression: output_str += f"MAE: {results[0]} | RMSE: {results[1]} | MSE: {results[2]} | R2: {results[3]}"
    else: output_str += f"Accuracy: {results[0]} | ROC-AUC: {results[1]} | Precision: {results[2]} | Recall: {results[3]} | F1: {results[4]}"
    return (output_str)

def run_nn(X_train, X_test, X_valid, y_train, y_test, y_valid, hidden_layer_sizes, activation, alpha, max_iter, regression=False):
    if regression:
        name = "MLPRegressor"
        model = MLPRegressor(hidden_layer_sizes=hidden_layer_sizes, activation=activation, alpha=alpha, max_iter=max_iter)
    else:
        name = "MLPClassifier"
        model = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, activation=activation, alpha=alpha, max_iter=max_iter)
         
    model.fit(X_train, y_train)
    y_predicted = model.predict(X_test)
    results = results_metrics(y_test, y_predicted, regression)

    output_str = f"Model: {name}-{hidden_layer_sizes}-{activation}-{alpha}-{max_iter} | "
    if regression: output_str += f"MAE: {results[0]} | RMSE: {results[1]} | MSE: {results[2]} | R2: {results[3]}"
    else: output_str += f"Accuracy: {results[0]} | ROC-AUC: {results[1]} | Precision: {results[2]} | Recall: {results[3]} | F1: {results[4]}"
    return (output_str)

def run_gb(X_train, X_test, X_valid, y_train, y_test, y_valid, n_estimators, learning_rate, regression=False):
    if regression:
        name = "GradientBoostingRegressor"
        model = GradientBoostingRegressor(n_estimators=n_estimators, learning_rate=learning_rate)
    else:
        name = "GradientBoostingClassifier"
        model = GradientBoostingClassifier(n_estimators=n_estimators, learning_rate=learning_rate)

    model.fit(X_train, y_train)
    y_predicted = model.predict(X_test)
    results = results_metrics(y_test, y_predicted, regression)
    
    output_str = f"Model: {name}-{n_estimators}-{learning_rate} | "
    if regression: output_str += f"MAE: {results[0]} | RMSE: {results[1]} | MSE: {results[2]} | R2: {results[3]}"
    else: output_str += f"Accuracy: {results[0]} | ROC-AUC: {results[1]} | Precision: {results[2]} | Recall: {results[3]} | F1: {results[4]}"
    return output_str

def run_svm(X_train, X_test, X_valid, y_train, y_test, y_valid, c, d, e, regression=False):
    if regression:
        name = "SVR"
        model = SVR(C=c, degree=d, epsilon=e, kernel="poly")
    else:
        name = "SVC"
        model = SVC(C=c, degree=d, kernel="poly") ### Epsilon is ignored

    model.fit(X_train, y_train)
    y_predicted = model.predict(X_test)
    results = results_metrics(y_test, y_predicted, regression)
    
    output_str = f"Model: {name}-{c}-{d}-{e} | "
    if regression: output_str += f"MAE: {results[0]} | RMSE: {results[1]} | MSE: {results[2]} | R2: {results[3]}"
    else: output_str += f"Accuracy: {results[0]} | ROC-AUC: {results[1]} | Precision: {results[2]} | Recall: {results[3]} | F1: {results[4]}"
    return output_str

# %%
def run_all(X_train, X_test, X_valid, y_train, y_test, y_valid, regression=False):
    results = []

    print("Run")

    #### -----

    param_grid_rf={
        'n_estimators': [50, 100],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    }
    param_combinations = list(product(*param_grid_rf.values()))
    for combination in param_combinations:
        n, m, s, l = combination
        results.append(run_rf(X_train, X_test, X_valid, y_train, y_test, y_valid, n, m, s, l, regression))
        print(results[-1])
    ### -----

    param_grid_lr = {
        'C': [0.001, 0.01, 0.1, 1, 10, 100],
        'penalty': ['l1', 'l2'],
        'solver': ['liblinear', 'saga']
    }
    if regression:
        param_grid_lr = {
            'C': [0.001],
            'penalty': ['l1'],
            'solver': ['liblinear']
        }
    param_combinations = list(product(*param_grid_lr.values()))
    for combination in param_combinations:
        C, p, s = combination
        results.append(run_lr(X_train, X_test, X_valid, y_train, y_test, y_valid, C, p, s, regression))
        print(results[-1])
    ### -----

    param_grid_mlp = {
        'hidden_layer_sizes': [(50,), (100,), (50, 50)],
        'activation': ['relu', 'tanh'],
        'alpha': [0.0001, 0.001, 0.01],
        'max_iter': [200, 500, 1000]
    }
    param_combinations = list(product(*param_grid_mlp.values()))
    for combination in param_combinations:
        h, ac, a, i = combination
        results.append(run_nn(X_train, X_test, X_valid, y_train, y_test, y_valid, h, ac, a, i, regression))
        print(results[-1])
    ### -----

    param_grid_gb={
        'n_estimators': [10, 100, 200], 
        'learning_rate': [0.1,0.5,1.0,2.0]
    }
    param_combinations = list(product(*param_grid_gb.values()))
    for combination in param_combinations:
        n, lr = combination
        results.append(run_gb(X_train, X_test, X_valid, y_train, y_test, y_valid, n, lr, regression))
        print(results[-1])
    ### -----
    
    param_grid_svm = {
        'C': [0.01, 0.1, 1, 10, 100, 1000],
        'degree': [2, 3, 4, 5],
        'epsilon': ["no epsilon"]
    }
    
    if regression:
        param_grid_svm = {
            'C': [0.01, 0.1, 1, 10, 100, 1000],
            'degree': [2, 3, 4],
            'epsilon': [0.01, 0.1, 1]
        }
        param_combinations = list(product(*param_grid_svm.values()))
        for combination in param_combinations:
            c, d, e = combination
            results.append(run_svm(X_train, X_test, X_valid, y_train, y_test, y_valid, c, d, e, regression))
            print(results[-1])
    
    return results

# %%
def run_configured(regression=False, pca=False):
    sc = StandardScaler()

    if regression:
        X_train = X_train_regre
        X_test =  X_test_regre
        X_valid = X_valid_regre
        y_train = y_train_regre
        y_test =  y_test_regre
        y_valid = y_valid_regre
    else:
        X_train = X_train_class
        X_test =  X_test_class
        X_valid = X_valid_class
        y_train = y_train_class
        y_test =  y_test_class
        y_valid = y_valid_class

    if pca:
        pca = PCA(n_components=0.95)
        X_train = pca.fit_transform(X_train)
        X_test =  pca.fit_transform(X_test)
        X_valid = pca.fit_transform(X_valid)

    results = run_all(X_train, X_test, X_valid, y_train, y_test, y_valid, regression=regression)

    csv_path = "BACE_comparison_results_"
    if scaffold: csv_path = "Scaffold\\" + csv_path
    else: csv_path = "No_scaffold\\" + csv_path
    if regression: csv_path += "regression" 
    else: csv_path += "classification"
    if not scaffold: csv_path += "_no"
    csv_path += "_scaffold"
    if pca: csv_path += "_pca"
    csv_path += "_svm.csv"
    
    dir_path = os.path.join(os.path.dirname(os.getcwd()), "BACE", csv_path)
    print(dir_path)
    
    data = [[j.split(":")[1] for j in i.split(" | ")] for i in results]
    #for index, row in enumerate(data):
    #    data[index].insert(0, data_tuples[0][index])
        
    print(data[0])
    
    #data_tuples = [tuple(item.split('; ')) for item in results]
    
    column_names = [i.split(":")[0] for i in results[0].split(" | ")]
    print(column_names)
    df = pd.DataFrame(data, columns=column_names)
    
    df.to_csv(dir_path)

    return

# %%
run_grid = {
        'regression': [False, True],
        'pca': [False, True]
    }

run_param_combinations = list(product(*run_grid.values()))

for combination in run_param_combinations:
    r, p = combination
    run_configured(r, p)
# Out:
# Run
# Model: RandomForestClassifier-50-None-2-1 | Accuracy: 0.7960526315789473 | ROC-AUC: 0.796969696969697 | Precision: 0.8484848484848485 | Recall: 0.7272727272727273 | F1: 0.7832167832167832
# Model: RandomForestClassifier-50-None-2-2 | Accuracy: 0.7960526315789473 | ROC-AUC: 0.7967965367965367 | Precision: 0.8382352941176471 | Recall: 0.7402597402597403 | F1: 0.7862068965517242
# Model: RandomForestClassifier-50-None-2-4 | Accuracy: 0.7960526315789473 | ROC-AUC: 0.796969696969697 | Precision: 0.8484848484848485 | Recall: 0.7272727272727273 | F1: 0.7832167832167832
# Model: RandomForestClassifier-50-None-5-1 | Accuracy: 0.8157894736842105 | ROC-AUC: 0.8164502164502165 | Precision: 0.855072463768116 | Recall: 0.7662337662337663 | F1: 0.8082191780821918
# Model: RandomForestClassifier-50-None-5-2 | Accuracy: 0.8223684210526315 | ROC-AUC: 0.822943722943723 | Precision: 0.8571428571428571 | Recall: 0.7792207792207793 | F1: 0.8163265306122449
# Model: RandomForestClassifier-50-None-5-4 | Accuracy: 0.8223684210526315 | ROC-AUC: 0.8234632034632033 | Precision: 0.890625 | Recall: 0.7402597402597403 | F1: 0.8085106382978724
# Model: RandomForestClassifier-50-None-10-1 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.8101298701298701 | Precision: 0.8636363636363636 | Recall: 0.7402597402597403 | F1: 0.7972027972027972
# Model: RandomForestClassifier-50-None-10-2 | Accuracy: 0.8223684210526315 | ROC-AUC: 0.822943722943723 | Precision: 0.8571428571428571 | Recall: 0.7792207792207793 | F1: 0.8163265306122449
# Model: RandomForestClassifier-50-None-10-4 | Accuracy: 0.7960526315789473 | ROC-AUC: 0.7967965367965367 | Precision: 0.8382352941176471 | Recall: 0.7402597402597403 | F1: 0.7862068965517242
# Model: RandomForestClassifier-50-10-2-1 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.8094372294372294 | Precision: 0.8243243243243243 | Recall: 0.7922077922077922 | F1: 0.8079470198675496
# Model: RandomForestClassifier-50-10-2-2 | Accuracy: 0.8157894736842105 | ROC-AUC: 0.8164502164502165 | Precision: 0.855072463768116 | Recall: 0.7662337662337663 | F1: 0.8082191780821918
# Model: RandomForestClassifier-50-10-2-4 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.80995670995671 | Precision: 0.8529411764705882 | Recall: 0.7532467532467533 | F1: 0.7999999999999999
# Model: RandomForestClassifier-50-10-5-1 | Accuracy: 0.8289473684210527 | ROC-AUC: 0.8294372294372294 | Precision: 0.8591549295774648 | Recall: 0.7922077922077922 | F1: 0.8243243243243243
# Model: RandomForestClassifier-50-10-5-2 | Accuracy: 0.8157894736842105 | ROC-AUC: 0.8161038961038961 | Precision: 0.8356164383561644 | Recall: 0.7922077922077922 | F1: 0.8133333333333332
# Model: RandomForestClassifier-50-10-5-4 | Accuracy: 0.8157894736842105 | ROC-AUC: 0.8166233766233767 | Precision: 0.8656716417910447 | Recall: 0.7532467532467533 | F1: 0.8055555555555556
# Model: RandomForestClassifier-50-10-10-1 | Accuracy: 0.8289473684210527 | ROC-AUC: 0.8292640692640691 | Precision: 0.8493150684931506 | Recall: 0.8051948051948052 | F1: 0.8266666666666668
# Model: RandomForestClassifier-50-10-10-2 | Accuracy: 0.7894736842105263 | ROC-AUC: 0.78995670995671 | Precision: 0.8169014084507042 | Recall: 0.7532467532467533 | F1: 0.7837837837837838
# Model: RandomForestClassifier-50-10-10-4 | Accuracy: 0.8026315789473685 | ROC-AUC: 0.8034632034632034 | Precision: 0.8507462686567164 | Recall: 0.7402597402597403 | F1: 0.7916666666666667
# Model: RandomForestClassifier-50-20-2-1 | Accuracy: 0.8026315789473685 | ROC-AUC: 0.8036363636363636 | Precision: 0.8615384615384616 | Recall: 0.7272727272727273 | F1: 0.7887323943661972
# Model: RandomForestClassifier-50-20-2-2 | Accuracy: 0.7960526315789473 | ROC-AUC: 0.796969696969697 | Precision: 0.8484848484848485 | Recall: 0.7272727272727273 | F1: 0.7832167832167832
# Model: RandomForestClassifier-50-20-2-4 | Accuracy: 0.7894736842105263 | ROC-AUC: 0.7904761904761906 | Precision: 0.8461538461538461 | Recall: 0.7142857142857143 | F1: 0.7746478873239436
# Model: RandomForestClassifier-50-20-5-1 | Accuracy: 0.8157894736842105 | ROC-AUC: 0.8164502164502165 | Precision: 0.855072463768116 | Recall: 0.7662337662337663 | F1: 0.8082191780821918
# Model: RandomForestClassifier-50-20-5-2 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.80995670995671 | Precision: 0.8529411764705882 | Recall: 0.7532467532467533 | F1: 0.7999999999999999
# Model: RandomForestClassifier-50-20-5-4 | Accuracy: 0.8157894736842105 | ROC-AUC: 0.8167965367965367 | Precision: 0.8769230769230769 | Recall: 0.7402597402597403 | F1: 0.8028169014084509
# Model: RandomForestClassifier-50-20-10-1 | Accuracy: 0.8026315789473685 | ROC-AUC: 0.8034632034632034 | Precision: 0.8507462686567164 | Recall: 0.7402597402597403 | F1: 0.7916666666666667
# Model: RandomForestClassifier-50-20-10-2 | Accuracy: 0.8289473684210527 | ROC-AUC: 0.8297835497835498 | Precision: 0.8805970149253731 | Recall: 0.7662337662337663 | F1: 0.8194444444444445
# Model: RandomForestClassifier-50-20-10-4 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.8101298701298701 | Precision: 0.8636363636363636 | Recall: 0.7402597402597403 | F1: 0.7972027972027972
# Model: RandomForestClassifier-100-None-2-1 | Accuracy: 0.8026315789473685 | ROC-AUC: 0.8032900432900432 | Precision: 0.8405797101449275 | Recall: 0.7532467532467533 | F1: 0.7945205479452054
# Model: RandomForestClassifier-100-None-2-2 | Accuracy: 0.8223684210526315 | ROC-AUC: 0.822943722943723 | Precision: 0.8571428571428571 | Recall: 0.7792207792207793 | F1: 0.8163265306122449
# Model: RandomForestClassifier-100-None-2-4 | Accuracy: 0.8157894736842105 | ROC-AUC: 0.8167965367965367 | Precision: 0.8769230769230769 | Recall: 0.7402597402597403 | F1: 0.8028169014084509
# Model: RandomForestClassifier-100-None-5-1 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.80995670995671 | Precision: 0.8529411764705882 | Recall: 0.7532467532467533 | F1: 0.7999999999999999
# Model: RandomForestClassifier-100-None-5-2 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.80995670995671 | Precision: 0.8529411764705882 | Recall: 0.7532467532467533 | F1: 0.7999999999999999
# Model: RandomForestClassifier-100-None-5-4 | Accuracy: 0.8157894736842105 | ROC-AUC: 0.8167965367965367 | Precision: 0.8769230769230769 | Recall: 0.7402597402597403 | F1: 0.8028169014084509
# Model: RandomForestClassifier-100-None-10-1 | Accuracy: 0.8223684210526315 | ROC-AUC: 0.8231168831168832 | Precision: 0.8676470588235294 | Recall: 0.7662337662337663 | F1: 0.8137931034482758
# Model: RandomForestClassifier-100-None-10-2 | Accuracy: 0.8223684210526315 | ROC-AUC: 0.8227705627705627 | Precision: 0.8472222222222222 | Recall: 0.7922077922077922 | F1: 0.8187919463087249
# Model: RandomForestClassifier-100-None-10-4 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.8101298701298701 | Precision: 0.8636363636363636 | Recall: 0.7402597402597403 | F1: 0.7972027972027972
# Model: RandomForestClassifier-100-10-2-1 | Accuracy: 0.8026315789473685 | ROC-AUC: 0.802943722943723 | Precision: 0.821917808219178 | Recall: 0.7792207792207793 | F1: 0.7999999999999999
# Model: RandomForestClassifier-100-10-2-2 | Accuracy: 0.8289473684210527 | ROC-AUC: 0.8294372294372294 | Precision: 0.8591549295774648 | Recall: 0.7922077922077922 | F1: 0.8243243243243243
# Model: RandomForestClassifier-100-10-2-4 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.8097835497835498 | Precision: 0.8428571428571429 | Recall: 0.7662337662337663 | F1: 0.8027210884353742
# Model: RandomForestClassifier-100-10-5-1 | Accuracy: 0.8223684210526315 | ROC-AUC: 0.8231168831168832 | Precision: 0.8676470588235294 | Recall: 0.7662337662337663 | F1: 0.8137931034482758
# Model: RandomForestClassifier-100-10-5-2 | Accuracy: 0.8223684210526315 | ROC-AUC: 0.8227705627705627 | Precision: 0.8472222222222222 | Recall: 0.7922077922077922 | F1: 0.8187919463087249
# Model: RandomForestClassifier-100-10-5-4 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.80995670995671 | Precision: 0.8529411764705882 | Recall: 0.7532467532467533 | F1: 0.7999999999999999
# Model: RandomForestClassifier-100-10-10-1 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.8097835497835498 | Precision: 0.8428571428571429 | Recall: 0.7662337662337663 | F1: 0.8027210884353742
# Model: RandomForestClassifier-100-10-10-2 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.8097835497835498 | Precision: 0.8428571428571429 | Recall: 0.7662337662337663 | F1: 0.8027210884353742
# Model: RandomForestClassifier-100-10-10-4 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.8097835497835498 | Precision: 0.8428571428571429 | Recall: 0.7662337662337663 | F1: 0.8027210884353742
# Model: RandomForestClassifier-100-20-2-1 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.80995670995671 | Precision: 0.8529411764705882 | Recall: 0.7532467532467533 | F1: 0.7999999999999999
# Model: RandomForestClassifier-100-20-2-2 | Accuracy: 0.7894736842105263 | ROC-AUC: 0.7903030303030303 | Precision: 0.835820895522388 | Recall: 0.7272727272727273 | F1: 0.7777777777777778
# Model: RandomForestClassifier-100-20-2-4 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.80995670995671 | Precision: 0.8529411764705882 | Recall: 0.7532467532467533 | F1: 0.7999999999999999
# Model: RandomForestClassifier-100-20-5-1 | Accuracy: 0.8223684210526315 | ROC-AUC: 0.8231168831168832 | Precision: 0.8676470588235294 | Recall: 0.7662337662337663 | F1: 0.8137931034482758
# Model: RandomForestClassifier-100-20-5-2 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.8097835497835498 | Precision: 0.8428571428571429 | Recall: 0.7662337662337663 | F1: 0.8027210884353742
# Model: RandomForestClassifier-100-20-5-4 | Accuracy: 0.8157894736842105 | ROC-AUC: 0.8167965367965367 | Precision: 0.8769230769230769 | Recall: 0.7402597402597403 | F1: 0.8028169014084509
# Model: RandomForestClassifier-100-20-10-1 | Accuracy: 0.7960526315789473 | ROC-AUC: 0.7966233766233766 | Precision: 0.8285714285714286 | Recall: 0.7532467532467533 | F1: 0.7891156462585034
# Model: RandomForestClassifier-100-20-10-2 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.80995670995671 | Precision: 0.8529411764705882 | Recall: 0.7532467532467533 | F1: 0.7999999999999999
# Model: RandomForestClassifier-100-20-10-4 | Accuracy: 0.8289473684210527 | ROC-AUC: 0.8296103896103897 | Precision: 0.8695652173913043 | Recall: 0.7792207792207793 | F1: 0.821917808219178
# Model: LogisticRegression-0.001-l1-liblinear | Accuracy: 0.6381578947368421 | ROC-AUC: 0.6404329004329004 | Precision: 0.72 | Recall: 0.4675324675324675 | F1: 0.5669291338582677
# Model: LogisticRegression-0.001-l1-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-0.001-l2-liblinear | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-0.001-l2-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-0.01-l1-liblinear | Accuracy: 0.6710526315789473 | ROC-AUC: 0.6723809523809524 | Precision: 0.7213114754098361 | Recall: 0.5714285714285714 | F1: 0.6376811594202898
# Model: LogisticRegression-0.01-l1-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-0.01-l2-liblinear | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-0.01-l2-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-0.1-l1-liblinear | Accuracy: 0.7236842105263158 | ROC-AUC: 0.7246753246753247 | Precision: 0.7692307692307693 | Recall: 0.6493506493506493 | F1: 0.7042253521126761
# Model: LogisticRegression-0.1-l1-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-0.1-l2-liblinear | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-0.1-l2-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-1-l1-liblinear | Accuracy: 0.7894736842105263 | ROC-AUC: 0.7896103896103897 | Precision: 0.8 | Recall: 0.7792207792207793 | F1: 0.7894736842105264
# Model: LogisticRegression-1-l1-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-1-l2-liblinear | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-1-l2-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-10-l1-liblinear | Accuracy: 0.7894736842105263 | ROC-AUC: 0.7897835497835499 | Precision: 0.8082191780821918 | Recall: 0.7662337662337663 | F1: 0.7866666666666666
# Model: LogisticRegression-10-l1-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-10-l2-liblinear | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-10-l2-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-100-l1-liblinear | Accuracy: 0.7960526315789473 | ROC-AUC: 0.7962770562770564 | Precision: 0.8108108108108109 | Recall: 0.7792207792207793 | F1: 0.794701986754967
# Model: LogisticRegression-100-l1-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-100-l2-liblinear | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-100-l2-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: MLPClassifier-(50,)-relu-0.0001-200 | Accuracy: 0.5394736842105263 | ROC-AUC: 0.5348917748917749 | Precision: 0.5271317829457365 | Recall: 0.8831168831168831 | F1: 0.6601941747572817
# Model: MLPClassifier-(50,)-relu-0.0001-500 | Accuracy: 0.5921052631578947 | ROC-AUC: 0.5963636363636363 | Precision: 0.7777777777777778 | Recall: 0.2727272727272727 | F1: 0.40384615384615374
# Model: MLPClassifier-(50,)-relu-0.0001-1000 | Accuracy: 0.631578947368421 | ROC-AUC: 0.634978354978355 | Precision: 0.7837837837837838 | Recall: 0.37662337662337664 | F1: 0.5087719298245614
# Model: MLPClassifier-(50,)-relu-0.001-200 | Accuracy: 0.6447368421052632 | ROC-AUC: 0.643982683982684 | Precision: 0.6352941176470588 | Recall: 0.7012987012987013 | F1: 0.6666666666666666
# Model: MLPClassifier-(50,)-relu-0.001-500 | Accuracy: 0.5657894736842105 | ROC-AUC: 0.5622510822510822 | Precision: 0.5470085470085471 | Recall: 0.8311688311688312 | F1: 0.6597938144329897
# Model: MLPClassifier-(50,)-relu-0.001-1000 | Accuracy: 0.618421052631579 | ROC-AUC: 0.616969696969697 | Precision: 0.6021505376344086 | Recall: 0.7272727272727273 | F1: 0.6588235294117646
# Model: MLPClassifier-(50,)-relu-0.01-200 | Accuracy: 0.5657894736842105 | ROC-AUC: 0.5639826839826839 | Precision: 0.5567010309278351 | Recall: 0.7012987012987013 | F1: 0.6206896551724138
# Model: MLPClassifier-(50,)-relu-0.01-500 | Accuracy: 0.5 | ROC-AUC: 0.5056277056277056 | Precision: 0.5454545454545454 | Recall: 0.07792207792207792 | F1: 0.13636363636363635
# Model: MLPClassifier-(50,)-relu-0.01-1000 | Accuracy: 0.6513157894736842 | ROC-AUC: 0.6492640692640693 | Precision: 0.62 | Recall: 0.8051948051948052 | F1: 0.7005649717514124
# Model: MLPClassifier-(50,)-tanh-0.0001-200 | Accuracy: 0.6118421052631579 | ROC-AUC: 0.6127272727272727 | Precision: 0.6363636363636364 | Recall: 0.5454545454545454 | F1: 0.5874125874125874
# Model: MLPClassifier-(50,)-tanh-0.0001-500 | Accuracy: 0.4473684210526316 | ROC-AUC: 0.4514285714285714 | Precision: 0.3793103448275862 | Recall: 0.14285714285714285 | F1: 0.20754716981132074
# Model: MLPClassifier-(50,)-tanh-0.0001-1000 | Accuracy: 0.5460526315789473 | ROC-AUC: 0.5493506493506494 | Precision: 0.6052631578947368 | Recall: 0.2987012987012987 | F1: 0.39999999999999997
# Model: MLPClassifier-(50,)-tanh-0.001-200 | Accuracy: 0.4605263157894737 | ROC-AUC: 0.4644155844155844 | Precision: 0.41935483870967744 | Recall: 0.16883116883116883 | F1: 0.24074074074074076
# Model: MLPClassifier-(50,)-tanh-0.001-500 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: MLPClassifier-(50,)-tanh-0.001-1000 | Accuracy: 0.5723684210526315 | ROC-AUC: 0.5746320346320346 | Precision: 0.62 | Recall: 0.4025974025974026 | F1: 0.4881889763779527
# Model: MLPClassifier-(50,)-tanh-0.01-200 | Accuracy: 0.5197368421052632 | ROC-AUC: 0.524069264069264 | Precision: 0.5769230769230769 | Recall: 0.19480519480519481 | F1: 0.29126213592233013
# Model: MLPClassifier-(50,)-tanh-0.01-500 | Accuracy: 0.5592105263157895 | ROC-AUC: 0.5574891774891775 | Precision: 0.5520833333333334 | Recall: 0.6883116883116883 | F1: 0.6127167630057804
# Model: MLPClassifier-(50,)-tanh-0.01-1000 | Accuracy: 0.5328947368421053 | ROC-AUC: 0.5356709956709956 | Precision: 0.5681818181818182 | Recall: 0.3246753246753247 | F1: 0.4132231404958678
# Model: MLPClassifier-(100,)-relu-0.0001-200 | Accuracy: 0.5197368421052632 | ROC-AUC: 0.5167965367965368 | Precision: 0.5181818181818182 | Recall: 0.7402597402597403 | F1: 0.609625668449198
# Model: MLPClassifier-(100,)-relu-0.0001-500 | Accuracy: 0.5921052631578947 | ROC-AUC: 0.5956709956709957 | Precision: 0.7142857142857143 | Recall: 0.3246753246753247 | F1: 0.44642857142857145
# Model: MLPClassifier-(100,)-relu-0.0001-1000 | Accuracy: 0.5657894736842105 | ROC-AUC: 0.5620779220779221 | Precision: 0.5462184873949579 | Recall: 0.8441558441558441 | F1: 0.6632653061224489
# Model: MLPClassifier-(100,)-relu-0.001-200 | Accuracy: 0.5197368421052632 | ROC-AUC: 0.5237229437229437 | Precision: 0.5666666666666667 | Recall: 0.22077922077922077 | F1: 0.31775700934579443
# Model: MLPClassifier-(100,)-relu-0.001-500 | Accuracy: 0.6578947368421053 | ROC-AUC: 0.6545454545454545 | Precision: 0.6086956521739131 | Recall: 0.9090909090909091 | F1: 0.7291666666666666
# Model: MLPClassifier-(100,)-relu-0.001-1000 | Accuracy: 0.4605263157894737 | ROC-AUC: 0.4561038961038961 | Precision: 0.48031496062992124 | Recall: 0.7922077922077922 | F1: 0.5980392156862745
# Model: MLPClassifier-(100,)-relu-0.01-200 | Accuracy: 0.6118421052631579 | ROC-AUC: 0.6116883116883117 | Precision: 0.6153846153846154 | Recall: 0.6233766233766234 | F1: 0.6193548387096774
# Model: MLPClassifier-(100,)-relu-0.01-500 | Accuracy: 0.6907894736842105 | ROC-AUC: 0.690995670995671 | Precision: 0.7027027027027027 | Recall: 0.6753246753246753 | F1: 0.6887417218543046
# Model: MLPClassifier-(100,)-relu-0.01-1000 | Accuracy: 0.625 | ROC-AUC: 0.6277922077922078 | Precision: 0.7272727272727273 | Recall: 0.4155844155844156 | F1: 0.5289256198347109
# Model: MLPClassifier-(100,)-tanh-0.0001-200 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.49809523809523804 | Precision: 0.5 | Recall: 0.14285714285714285 | F1: 0.22222222222222224
# Model: MLPClassifier-(100,)-tanh-0.0001-500 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.4998268398268398 | Precision: 0.5 | Recall: 0.012987012987012988 | F1: 0.025316455696202535
# Model: MLPClassifier-(100,)-tanh-0.0001-1000 | Accuracy: 0.5921052631578947 | ROC-AUC: 0.594978354978355 | Precision: 0.6744186046511628 | Recall: 0.37662337662337664 | F1: 0.48333333333333334
# Model: MLPClassifier-(100,)-tanh-0.001-200 | Accuracy: 0.5 | ROC-AUC: 0.5028571428571428 | Precision: 0.5116279069767442 | Recall: 0.2857142857142857 | F1: 0.36666666666666664
# Model: MLPClassifier-(100,)-tanh-0.001-500 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.49809523809523804 | Precision: 0.5 | Recall: 0.14285714285714285 | F1: 0.22222222222222224
# Model: MLPClassifier-(100,)-tanh-0.001-1000 | Accuracy: 0.5197368421052632 | ROC-AUC: 0.5218181818181818 | Precision: 0.5384615384615384 | Recall: 0.36363636363636365 | F1: 0.43410852713178294
# Model: MLPClassifier-(100,)-tanh-0.01-200 | Accuracy: 0.5592105263157895 | ROC-AUC: 0.5604329004329004 | Precision: 0.5806451612903226 | Recall: 0.4675324675324675 | F1: 0.5179856115107914
# Model: MLPClassifier-(100,)-tanh-0.01-500 | Accuracy: 0.5526315789473685 | ROC-AUC: 0.5565367965367966 | Precision: 0.6451612903225806 | Recall: 0.2597402597402597 | F1: 0.37037037037037035
# Model: MLPClassifier-(100,)-tanh-0.01-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5091774891774893 | Precision: 0.5217391304347826 | Recall: 0.3116883116883117 | F1: 0.39024390243902435
# Model: MLPClassifier-(50, 50)-relu-0.0001-200 | Accuracy: 0.4473684210526316 | ROC-AUC: 0.4457142857142857 | Precision: 0.4631578947368421 | Recall: 0.5714285714285714 | F1: 0.5116279069767442
# Model: MLPClassifier-(50, 50)-relu-0.0001-500 | Accuracy: 0.5263157894736842 | ROC-AUC: 0.5302164502164503 | Precision: 0.5806451612903226 | Recall: 0.23376623376623376 | F1: 0.33333333333333337
# Model: MLPClassifier-(50, 50)-relu-0.0001-1000 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.4889177489177489 | Precision: 0.5 | Recall: 0.8311688311688312 | F1: 0.624390243902439
# Model: MLPClassifier-(50, 50)-relu-0.001-200 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.4982683982683983 | Precision: 0.5 | Recall: 0.12987012987012986 | F1: 0.20618556701030924
# Model: MLPClassifier-(50, 50)-relu-0.001-500 | Accuracy: 0.5263157894736842 | ROC-AUC: 0.5317748917748917 | Precision: 0.6923076923076923 | Recall: 0.11688311688311688 | F1: 0.19999999999999998
# Model: MLPClassifier-(50, 50)-relu-0.001-1000 | Accuracy: 0.5789473684210527 | ROC-AUC: 0.5838961038961039 | Precision: 0.8421052631578947 | Recall: 0.2077922077922078 | F1: 0.33333333333333337
# Model: MLPClassifier-(50, 50)-relu-0.01-200 | Accuracy: 0.5394736842105263 | ROC-AUC: 0.5371428571428571 | Precision: 0.5339805825242718 | Recall: 0.7142857142857143 | F1: 0.6111111111111112
# Model: MLPClassifier-(50, 50)-relu-0.01-500 | Accuracy: 0.5328947368421053 | ROC-AUC: 0.5334199134199133 | Precision: 0.5428571428571428 | Recall: 0.4935064935064935 | F1: 0.5170068027210883
# Model: MLPClassifier-(50, 50)-relu-0.01-1000 | Accuracy: 0.5394736842105263 | ROC-AUC: 0.5445887445887446 | Precision: 0.7058823529411765 | Recall: 0.15584415584415584 | F1: 0.2553191489361702
# Model: MLPClassifier-(50, 50)-tanh-0.0001-200 | Accuracy: 0.5855263157894737 | ROC-AUC: 0.5864069264069264 | Precision: 0.6060606060606061 | Recall: 0.5194805194805194 | F1: 0.5594405594405594
# Model: MLPClassifier-(50, 50)-tanh-0.0001-500 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.4974025974025974 | Precision: 0.5 | Recall: 0.19480519480519481 | F1: 0.28037383177570097
# Model: MLPClassifier-(50, 50)-tanh-0.0001-1000 | Accuracy: 0.4868421052631579 | ROC-AUC: 0.49090909090909096 | Precision: 0.4827586206896552 | Recall: 0.18181818181818182 | F1: 0.2641509433962264
# Model: MLPClassifier-(50, 50)-tanh-0.001-200 | Accuracy: 0.5197368421052632 | ROC-AUC: 0.5223376623376623 | Precision: 0.5434782608695652 | Recall: 0.3246753246753247 | F1: 0.4065040650406504
# Model: MLPClassifier-(50, 50)-tanh-0.001-500 | Accuracy: 0.5328947368421053 | ROC-AUC: 0.5361904761904761 | Precision: 0.5789473684210527 | Recall: 0.2857142857142857 | F1: 0.38260869565217387
# Model: MLPClassifier-(50, 50)-tanh-0.001-1000 | Accuracy: 0.5 | ROC-AUC: 0.5051082251082251 | Precision: 0.5294117647058824 | Recall: 0.11688311688311688 | F1: 0.19148936170212763
# Model: MLPClassifier-(50, 50)-tanh-0.01-200 | Accuracy: 0.5526315789473685 | ROC-AUC: 0.5567099567099567 | Precision: 0.6551724137931034 | Recall: 0.24675324675324675 | F1: 0.3584905660377359
# Model: MLPClassifier-(50, 50)-tanh-0.01-500 | Accuracy: 0.5921052631578947 | ROC-AUC: 0.5925541125541126 | Precision: 0.6056338028169014 | Recall: 0.5584415584415584 | F1: 0.581081081081081
# Model: MLPClassifier-(50, 50)-tanh-0.01-1000 | Accuracy: 0.5526315789473685 | ROC-AUC: 0.5563636363636364 | Precision: 0.6363636363636364 | Recall: 0.2727272727272727 | F1: 0.3818181818181818
# Model: GradientBoostingClassifier-10-0.1 | Accuracy: 0.8157894736842105 | ROC-AUC: 0.8162770562770563 | Precision: 0.8450704225352113 | Recall: 0.7792207792207793 | F1: 0.8108108108108109
# Model: GradientBoostingClassifier-10-0.5 | Accuracy: 0.7894736842105263 | ROC-AUC: 0.7897835497835499 | Precision: 0.8082191780821918 | Recall: 0.7662337662337663 | F1: 0.7866666666666666
# Model: GradientBoostingClassifier-10-1.0 | Accuracy: 0.7828947368421053 | ROC-AUC: 0.7831168831168832 | Precision: 0.7972972972972973 | Recall: 0.7662337662337663 | F1: 0.7814569536423841
# Model: GradientBoostingClassifier-10-2.0 | Accuracy: 0.6842105263157895 | ROC-AUC: 0.6845021645021645 | Precision: 0.6986301369863014 | Recall: 0.6623376623376623 | F1: 0.68
# Model: GradientBoostingClassifier-100-0.1 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.8094372294372294 | Precision: 0.8243243243243243 | Recall: 0.7922077922077922 | F1: 0.8079470198675496
# Model: GradientBoostingClassifier-100-0.5 | Accuracy: 0.8092105263157895 | ROC-AUC: 0.8096103896103897 | Precision: 0.8333333333333334 | Recall: 0.7792207792207793 | F1: 0.8053691275167787
# Model: GradientBoostingClassifier-100-1.0 | Accuracy: 0.8223684210526315 | ROC-AUC: 0.8224242424242425 | Precision: 0.8289473684210527 | Recall: 0.8181818181818182 | F1: 0.8235294117647058
# Model: GradientBoostingClassifier-100-2.0 | Accuracy: 0.48026315789473684 | ROC-AUC: 0.47956709956709953 | Precision: 0.4880952380952381 | Recall: 0.5324675324675324 | F1: 0.5093167701863354
# Model: GradientBoostingClassifier-200-0.1 | Accuracy: 0.8157894736842105 | ROC-AUC: 0.815930735930736 | Precision: 0.8266666666666667 | Recall: 0.8051948051948052 | F1: 0.8157894736842106
# Model: GradientBoostingClassifier-200-0.5 | Accuracy: 0.8223684210526315 | ROC-AUC: 0.8227705627705627 | Precision: 0.8472222222222222 | Recall: 0.7922077922077922 | F1: 0.8187919463087249
# Model: GradientBoostingClassifier-200-1.0 | Accuracy: 0.8355263157894737 | ROC-AUC: 0.8355844155844155 | Precision: 0.8421052631578947 | Recall: 0.8311688311688312 | F1: 0.8366013071895425
# Model: GradientBoostingClassifier-200-2.0 | Accuracy: 0.48026315789473684 | ROC-AUC: 0.47956709956709953 | Precision: 0.4880952380952381 | Recall: 0.5324675324675324 | F1: 0.5093167701863354
# c:\Users\admin\Documents\GitHub\czasteczkowa-inzynierka\experiments\BACE\No_scaffold\BACE_comparison_results_classification_no_scaffold_svm.csv
# [' RandomForestClassifier-50-None-2-1', ' 0.7960526315789473', ' 0.796969696969697', ' 0.8484848484848485', ' 0.7272727272727273', ' 0.7832167832167832']
# ['Model', 'Accuracy', 'ROC-AUC', 'Precision', 'Recall', 'F1']
# Run
# Model: RandomForestClassifier-50-None-2-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-None-2-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-None-2-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-None-5-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-None-5-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-None-5-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-None-10-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-None-10-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-None-10-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-10-2-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-10-2-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-10-2-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-10-5-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-10-5-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-10-5-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-10-10-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-10-10-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-10-10-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-20-2-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-20-2-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-20-2-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-20-5-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-20-5-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-20-5-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-20-10-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-20-10-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-50-20-10-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-None-2-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-None-2-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-None-2-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-None-5-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-None-5-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-None-5-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-None-10-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-None-10-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-None-10-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-10-2-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-10-2-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-10-2-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-10-5-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-10-5-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-10-5-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-10-10-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-10-10-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-10-10-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-20-2-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-20-2-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-20-2-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-20-5-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-20-5-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-20-5-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-20-10-1 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-20-10-2 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: RandomForestClassifier-100-20-10-4 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: LogisticRegression-0.001-l1-liblinear | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: LogisticRegression-0.001-l1-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-0.001-l2-liblinear | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-0.001-l2-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-0.01-l1-liblinear | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: LogisticRegression-0.01-l1-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-0.01-l2-liblinear | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-0.01-l2-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-0.1-l1-liblinear | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: LogisticRegression-0.1-l1-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-0.1-l2-liblinear | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-0.1-l2-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-1-l1-liblinear | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: LogisticRegression-1-l1-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-1-l2-liblinear | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-1-l2-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-10-l1-liblinear | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: LogisticRegression-10-l1-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-10-l2-liblinear | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-10-l2-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-100-l1-liblinear | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: LogisticRegression-100-l1-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-100-l2-liblinear | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: LogisticRegression-100-l2-saga | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50,)-relu-0.0001-200 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: MLPClassifier-(50,)-relu-0.0001-500 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: MLPClassifier-(50,)-relu-0.0001-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50,)-relu-0.001-200 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50,)-relu-0.001-500 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: MLPClassifier-(50,)-relu-0.001-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50,)-relu-0.01-200 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.48718614718614717 | Precision: 0.5 | Recall: 0.961038961038961 | F1: 0.6577777777777777
# Model: MLPClassifier-(50,)-relu-0.01-500 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: MLPClassifier-(50,)-relu-0.01-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50,)-tanh-0.0001-200 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50,)-tanh-0.0001-500 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50,)-tanh-0.0001-1000 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.48718614718614717 | Precision: 0.5 | Recall: 0.961038961038961 | F1: 0.6577777777777777
# Model: MLPClassifier-(50,)-tanh-0.001-200 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50,)-tanh-0.001-500 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50,)-tanh-0.001-1000 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: MLPClassifier-(50,)-tanh-0.01-200 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: MLPClassifier-(50,)-tanh-0.01-500 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: MLPClassifier-(50,)-tanh-0.01-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(100,)-relu-0.0001-200 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: MLPClassifier-(100,)-relu-0.0001-500 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(100,)-relu-0.0001-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: MLPClassifier-(100,)-relu-0.001-200 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(100,)-relu-0.001-500 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: MLPClassifier-(100,)-relu-0.001-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(100,)-relu-0.01-200 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(100,)-relu-0.01-500 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(100,)-relu-0.01-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(100,)-tanh-0.0001-200 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(100,)-tanh-0.0001-500 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: MLPClassifier-(100,)-tanh-0.0001-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(100,)-tanh-0.001-200 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(100,)-tanh-0.001-500 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.48718614718614717 | Precision: 0.5 | Recall: 0.961038961038961 | F1: 0.6577777777777777
# Model: MLPClassifier-(100,)-tanh-0.001-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(100,)-tanh-0.01-200 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.48718614718614717 | Precision: 0.5 | Recall: 0.961038961038961 | F1: 0.6577777777777777
# Model: MLPClassifier-(100,)-tanh-0.01-500 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(100,)-tanh-0.01-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50, 50)-relu-0.0001-200 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50, 50)-relu-0.0001-500 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50, 50)-relu-0.0001-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50, 50)-relu-0.001-200 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50, 50)-relu-0.001-500 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: MLPClassifier-(50, 50)-relu-0.001-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: MLPClassifier-(50, 50)-relu-0.01-200 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5 | Precision: 0.506578947368421 | Recall: 1.0 | F1: 0.6724890829694323
# Model: MLPClassifier-(50, 50)-relu-0.01-500 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50, 50)-relu-0.01-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50, 50)-tanh-0.0001-200 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: MLPClassifier-(50, 50)-tanh-0.0001-500 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.48718614718614717 | Precision: 0.5 | Recall: 0.961038961038961 | F1: 0.6577777777777777
# Model: MLPClassifier-(50, 50)-tanh-0.0001-1000 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# Model: MLPClassifier-(50, 50)-tanh-0.001-200 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: MLPClassifier-(50, 50)-tanh-0.001-500 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: MLPClassifier-(50, 50)-tanh-0.001-1000 | Accuracy: 0.4934210526315789 | ROC-AUC: 0.5 | Precision: 0.0 | Recall: 0.0 | F1: 0.0
# Model: MLPClassifier-(50, 50)-tanh-0.01-200 | Accuracy: 0.5 | ROC-AUC: 0.5063203463203463 | Precision: 0.6666666666666666 | Recall: 0.025974025974025976 | F1: 0.05
# Model: MLPClassifier-(50, 50)-tanh-0.01-500 | Accuracy: 0.506578947368421 | ROC-AUC: 0.5128138528138528 | Precision: 0.75 | Recall: 0.03896103896103896 | F1: 0.07407407407407407
# ...
# Model: MLPRegressor-(50,)-relu-0.01-200 | MAE: 6.05538020447483 | RMSE: 6.203226798343003 | MSE: 38.48002271168079 | R2: -20.1116565978726
# Model: MLPRegressor-(50,)-relu-0.01-500 | MAE: 6.050082970818863 | RMSE: 6.200759812356536 | MSE: 38.44942225053587 | R2: -20.094867979210168
# Model: MLPRegressor-(50,)-relu-0.01-1000 | MAE: 7.4671361328246935 | RMSE: 10.838534908963362 | MSE: 117.47383897281743 | R2: -63.45077660713201
# Model: MLPRegressor-(50,)-tanh-0.0001-200 | MAE: 1.4291610008543898 | RMSE: 2.5652507308136627 | MSE: 6.58051131194003 | R2: -2.6103277822110673
# Model: MLPRegressor-(50,)-tanh-0.0001-500 | MAE: 1.4692034465208612 | RMSE: 2.635848321021084 | MSE: 6.947696371429668 | R2: -2.811779973180319
# Model: MLPRegressor-(50,)-tanh-0.0001-1000 | MAE: 1.4396509464811498 | RMSE: 2.5506149772985975 | MSE: 6.505636762419925 | R2: -2.5692486542377613
# Model: MLPRegressor-(50,)-tanh-0.001-200 | MAE: 1.4521086547491162 | RMSE: 2.5487574077449686 | MSE: 6.4961643235348525 | R2: -2.564051701045078
# Model: MLPRegressor-(50,)-tanh-0.001-500 | MAE: 1.477700167940604 | RMSE: 2.5812503949680785 | MSE: 6.662853601522861 | R2: -2.655504006616663
# Model: MLPRegressor-(50,)-tanh-0.001-1000 | MAE: 1.512122061894667 | RMSE: 2.5534495002087656 | MSE: 6.520104350116395 | R2: -2.5771861428805307
# Model: MLPRegressor-(50,)-tanh-0.01-200 | MAE: 1.518650037918625 | RMSE: 2.649470664439395 | MSE: 7.019694801724929 | R2: -2.851281148825884
# Model: MLPRegressor-(50,)-tanh-0.01-500 | MAE: 1.7838180020593166 | RMSE: 2.6397561135835867 | MSE: 6.968312339201923 | R2: -2.823090705382889
# Model: MLPRegressor-(50,)-tanh-0.01-1000 | MAE: 1.4601942519416138 | RMSE: 2.553300811274667 | MSE: 6.519345032855872 | R2: -2.5767695515138076
# Model: MLPRegressor-(100,)-relu-0.0001-200 | MAE: 34.98582695838985 | RMSE: 254.9761264446875 | MSE: 65012.82505673727 | R2: -35667.59737426212
# Model: MLPRegressor-(100,)-relu-0.0001-500 | MAE: 6.549939288197294 | RMSE: 6.687835155079623 | MSE: 44.727139061518876 | R2: -23.539070767893403
# Model: MLPRegressor-(100,)-relu-0.0001-1000 | MAE: 6.466643229026239 | RMSE: 6.607318032887021 | MSE: 43.656651587714016 | R2: -22.951759161852376
# Model: MLPRegressor-(100,)-relu-0.001-200 | MAE: 6.596626627104474 | RMSE: 6.732778773808441 | MSE: 45.33031001704549 | R2: -23.869994119428306
# Model: MLPRegressor-(100,)-relu-0.001-500 | MAE: 6.135538656209307 | RMSE: 6.31053035117831 | MSE: 39.82279331314265 | R2: -20.848353455880854
# Model: MLPRegressor-(100,)-relu-0.001-1000 | MAE: 6.41539522586177 | RMSE: 6.555522410893961 | MSE: 42.97487407973297 | R2: -22.57770915849102
# Model: MLPRegressor-(100,)-relu-0.01-200 | MAE: 5324.341361417219 | RMSE: 47807.50787518888 | MSE: 2285557809.2362466 | R2: -1253947065.6303573
# Model: MLPRegressor-(100,)-relu-0.01-500 | MAE: 35950.66114086053 | RMSE: 305421.9489147225 | MSE: 93282566878.86734 | R2: -51178491583.33388
# Model: MLPRegressor-(100,)-relu-0.01-1000 | MAE: 5.849803464049209 | RMSE: 6.005254694733962 | MSE: 36.06308394862429 | R2: -18.785628763480318
# Model: MLPRegressor-(100,)-tanh-0.0001-200 | MAE: 1.4215529846257433 | RMSE: 2.6024619409126006 | MSE: 6.7728081538985805 | R2: -2.715829406331782
# Model: MLPRegressor-(100,)-tanh-0.0001-500 | MAE: 1.4277826156807634 | RMSE: 2.570336824019423 | MSE: 6.606631388910255 | R2: -2.624658285585173
# Model: MLPRegressor-(100,)-tanh-0.0001-1000 | MAE: 1.5436690998504503 | RMSE: 2.573585717858139 | MSE: 6.6233434471633945 | R2: -2.6338271792089496
# Model: MLPRegressor-(100,)-tanh-0.001-200 | MAE: 1.7141216444179914 | RMSE: 2.5998530287536115 | MSE: 6.759235771119327 | R2: -2.7083830623782608
# Model: MLPRegressor-(100,)-tanh-0.001-500 | MAE: 1.8476843012194493 | RMSE: 2.6562094314091715 | MSE: 7.055448543507033 | R2: -2.870897060288526
# Model: MLPRegressor-(100,)-tanh-0.001-1000 | MAE: 1.59738048987729 | RMSE: 2.581809390483792 | MSE: 6.6657397287902915 | R2: -2.657087449750891
# Model: MLPRegressor-(100,)-tanh-0.01-200 | MAE: 1.4406930335293833 | RMSE: 2.652822396963546 | MSE: 7.037466669831413 | R2: -2.8610314958924117
# Model: MLPRegressor-(100,)-tanh-0.01-500 | MAE: 1.4605777596202651 | RMSE: 2.542834755241018 | MSE: 6.466008592461648 | R2: -2.5475070788226484
# Model: MLPRegressor-(100,)-tanh-0.01-1000 | MAE: 1.629905721826041 | RMSE: 2.6204990982280063 | MSE: 6.8670155238137935 | R2: -2.767515281299704
# Model: MLPRegressor-(50, 50)-relu-0.0001-200 | MAE: 1072530.8271536366 | RMSE: 9487904.945387227 | MSE: 90020340252703.42 | R2: -49388705523341.2
# Model: MLPRegressor-(50, 50)-relu-0.0001-500 | MAE: 297.39892926576175 | RMSE: 2507.374302160601 | MSE: 6286925.891135361 | R2: -3449254.2528986395
# Model: MLPRegressor-(50, 50)-relu-0.0001-1000 | MAE: 683.1088940540241 | RMSE: 6071.469810853163 | MSE: 36862745.66410135 | R2: -20224353.68778942
# Model: MLPRegressor-(50, 50)-relu-0.001-200 | MAE: 509938.24575763056 | RMSE: 4576317.5217380775 | MSE: 20942682059766.94 | R2: -11489980533456.814
# Model: MLPRegressor-(50, 50)-relu-0.001-500 | MAE: 564.9962661797744 | RMSE: 5055.048615680129 | MSE: 25553516.506889585 | R2: -14019664.981064016
# Model: MLPRegressor-(50, 50)-relu-0.001-1000 | MAE: 327.57312508981073 | RMSE: 2731.341351133607 | MSE: 7460225.576412359 | R2: -4092972.6890221415
# Model: MLPRegressor-(50, 50)-relu-0.01-200 | MAE: 78.56432682401075 | RMSE: 566.9559605039718 | MSE: 321439.06115098123 | R2: -176353.13385819367
# Model: MLPRegressor-(50, 50)-relu-0.01-500 | MAE: 89985.96726142814 | RMSE: 805509.6961235424 | MSE: 648845870549.0415 | R2: -355982409536.94727
# Model: MLPRegressor-(50, 50)-relu-0.01-1000 | MAE: 19052.312143346844 | RMSE: 151798.57855540887 | MSE: 23042808451.44264 | R2: -12642192617.294445
# Model: MLPRegressor-(50, 50)-tanh-0.0001-200 | MAE: 1.4536018744848505 | RMSE: 2.6582391672380297 | MSE: 7.0662354702383325 | R2: -2.8768151933053363
# Model: MLPRegressor-(50, 50)-tanh-0.0001-500 | MAE: 1.4443965495224147 | RMSE: 2.5323955847110056 | MSE: 6.413027397463797 | R2: -2.5184395077528414
# Model: MLPRegressor-(50, 50)-tanh-0.0001-1000 | MAE: 1.4233352919286382 | RMSE: 2.507553775747716 | MSE: 6.287825938266628 | R2: -2.4497490542173024
# Model: MLPRegressor-(50, 50)-tanh-0.001-200 | MAE: 1.479254164028717 | RMSE: 2.6006327271277754 | MSE: 6.76329058140805 | R2: -2.7106076910648507
# Model: MLPRegressor-(50, 50)-tanh-0.001-500 | MAE: 1.4668456142242816 | RMSE: 2.5763565420314127 | MSE: 6.637613031668059 | R2: -2.6416560354992384
# Model: MLPRegressor-(50, 50)-tanh-0.001-1000 | MAE: 1.5162973562659772 | RMSE: 2.5770794266091515 | MSE: 6.641338371052152 | R2: -2.643699903466178
# Model: MLPRegressor-(50, 50)-tanh-0.01-200 | MAE: 1.4296861242710377 | RMSE: 2.593631654845427 | MSE: 6.726925161016228 | R2: -2.6906561886163773
# Model: MLPRegressor-(50, 50)-tanh-0.01-500 | MAE: 1.4505655672181101 | RMSE: 2.6272616498850847 | MSE: 6.902503776956896 | R2: -2.7869855352345625
# Model: MLPRegressor-(50, 50)-tanh-0.01-1000 | MAE: 1.4415288593315099 | RMSE: 2.6661964921623604 | MSE: 7.1086037348188755 | R2: -2.9000600925917577
# Model: GradientBoostingRegressor-10-0.1 | MAE: 1.8679157778918896 | RMSE: 2.2962580640883274 | MSE: 5.272801096890673 | R2: -1.8928664335910304
# Model: GradientBoostingRegressor-10-0.5 | MAE: 2.9419518895002477 | RMSE: 3.236938637328064 | MSE: 10.477771741827263 | R2: -4.74851840867556
# Model: GradientBoostingRegressor-10-1.0 | MAE: 2.961457059868421 | RMSE: 3.254676441543414 | MSE: 10.592918739137701 | R2: -4.811692588267615
# Model: GradientBoostingRegressor-10-2.0 | MAE: 1.114263524780702 | RMSE: 1.3522084102313645 | MSE: 1.8284675847004344 | R2: -0.003169359794044313
# Model: GradientBoostingRegressor-100-0.1 | MAE: 2.951850487079503 | RMSE: 3.2459377874143995 | MSE: 10.536112119764686 | R2: -4.780526238661353
# Model: GradientBoostingRegressor-100-0.5 | MAE: 2.9614570807479272 | RMSE: 3.25467646054185 | MSE: 10.592918862805224 | R2: -4.811692656116491
# Model: GradientBoostingRegressor-100-1.0 | MAE: 2.961457059868421 | RMSE: 3.254676441543414 | MSE: 10.592918739137701 | R2: -4.811692588267615
# Model: GradientBoostingRegressor-100-2.0 | MAE: 1.114263524780702 | RMSE: 1.3522084102313645 | MSE: 1.8284675847004344 | R2: -0.003169359794044313
# Model: GradientBoostingRegressor-200-0.1 | MAE: 2.9606514177198044 | RMSE: 3.253943398238432 | MSE: 10.588147638939475 | R2: -4.8090749747143775
# Model: GradientBoostingRegressor-200-0.5 | MAE: 2.961457059870169 | RMSE: 3.2546764415450045 | MSE: 10.592918739148052 | R2: -4.811692588273295
# Model: GradientBoostingRegressor-200-1.0 | MAE: 2.961457059868421 | RMSE: 3.254676441543414 | MSE: 10.592918739137701 | R2: -4.811692588267615
# Model: GradientBoostingRegressor-200-2.0 | MAE: 1.114263524780702 | RMSE: 1.3522084102313645 | MSE: 1.8284675847004344 | R2: -0.003169359794044313
# Model: SVR-0.01-2-0.01 | MAE: 1.0907025542543871 | RMSE: 1.3560821166447654 | MSE: 1.8389587070837474 | R2: -0.008925202890663009
# Model: SVR-0.01-2-0.1 | MAE: 1.0910657290468604 | RMSE: 1.3557169393090267 | MSE: 1.8379684195294355 | R2: -0.008381892120385537
# Model: SVR-0.01-2-1 | MAE: 1.1085993466337463 | RMSE: 1.3506207978016058 | MSE: 1.824176539454246 | R2: -0.0008151233019757509
# Model: SVR-0.01-3-0.01 | MAE: 1.0907023120856203 | RMSE: 1.356082363941102 | MSE: 1.838959377792087 | R2: -0.008925570867684307
# Model: SVR-0.01-3-0.1 | MAE: 1.0910654923283354 | RMSE: 1.355717173629799 | MSE: 1.8379690548747707 | R2: -0.008382240695869347
# Model: SVR-0.01-3-1 | MAE: 1.1085990752521504 | RMSE: 1.350620738942034 | MSE: 1.8241763804603257 | R2: -0.0008150360716467908
# Model: SVR-0.01-4-0.01 | MAE: 1.0907023128858833 | RMSE: 1.3560823631238863 | MSE: 1.8389593755756637 | R2: -0.008925569651667242
# Model: SVR-0.01-4-0.1 | MAE: 1.0910654925559953 | RMSE: 1.3557171734044433 | MSE: 1.8379690542637332 | R2: -0.008382240360630178
# Model: SVR-0.01-4-1 | MAE: 1.108599076092149 | RMSE: 1.350620739124215 | MSE: 1.824176380952441 | R2: -0.0008150363416403739
# Model: SVR-0.1-2-0.01 | MAE: 1.0907025542200712 | RMSE: 1.3560821166798074 | MSE: 1.8389587071787867 | R2: -0.0089252029428053
# Model: SVR-0.1-2-0.1 | MAE: 1.0910657290125443 | RMSE: 1.3557169393429949 | MSE: 1.8379684196215378 | R2: -0.00838189217091645
# Model: SVR-0.1-2-1 | MAE: 1.108599346590538 | RMSE: 1.350620797792234 | MSE: 1.8241765394289309 | R2: -0.0008151232880868609
# Model: SVR-0.1-3-0.01 | MAE: 1.0907023121183888 | RMSE: 1.3560823639076394 | MSE: 1.838959377701331 | R2: -0.008925570817892137
# Model: SVR-0.1-3-0.1 | MAE: 1.0910654923611038 | RMSE: 1.3557171735973625 | MSE: 1.8379690547868213 | R2: -0.008382240647616834
# Model: SVR-0.1-3-1 | MAE: 1.1085990752925607 | RMSE: 1.350620738950798 | MSE: 1.8241763804839999 | R2: -0.00081503608463529
# Model: SVR-0.1-4-0.01 | MAE: 1.0907023128271633 | RMSE: 1.3560823631838501 | MSE: 1.8389593757382956 | R2: -0.008925569740893646
# Model: SVR-0.1-4-0.1 | MAE: 1.0910654925168484 | RMSE: 1.3557171734431939 | MSE: 1.8379690543688028 | R2: -0.0083822404182754
# Model: SVR-0.1-4-1 | MAE: 1.1085990760211606 | RMSE: 1.350620739108819 | MSE: 1.8241763809108524 | R2: -0.0008150363188232923
# Model: SVR-1-2-0.01 | MAE: 1.0907025538769104 | RMSE: 1.3560821170302308 | MSE: 1.8389587081291925 | R2: -0.00892520346423531
# Model: SVR-1-2-0.1 | MAE: 1.0910657286693781 | RMSE: 1.3557169396826818 | MSE: 1.8379684205425766 | R2: -0.008381892676234681
# Model: SVR-1-2-1 | MAE: 1.1085993461584451 | RMSE: 1.3506207976985154 | MSE: 1.8241765391757743 | R2: -0.0008151231491952959
# Model: SVR-1-3-0.01 | MAE: 1.0907023124460729 | RMSE: 1.3560823635730135 | MSE: 1.8389593767937706 | R2: -0.008925570319968656
# Model: SVR-1-3-0.1 | MAE: 1.0910654926887884 | RMSE: 1.3557171732729938 | MSE: 1.8379690539073168 | R2: -0.00838224016508593
# Model: SVR-1-3-1 | MAE: 1.1085990756966662 | RMSE: 1.3506207390384417 | MSE: 1.8241763807207463 | R2: -0.0008150362145236123
# Model: SVR-1-4-0.01 | MAE: 1.0907023122399648 | RMSE: 1.3560823637834878 | MSE: 1.8389593773646116 | R2: -0.008925570633154578
# Model: SVR-1-4-0.1 | MAE: 1.0910654921253826 | RMSE: 1.3557171738306983 | MSE: 1.837969055419496 | R2: -0.008382240994727175
# Model: SVR-1-4-1 | MAE: 1.1085990753112762 | RMSE: 1.350620738954857 | MSE: 1.8241763804949642 | R2: -0.0008150360906507004
# Model: SVR-10-2-0.01 | MAE: 1.0907025529375032 | RMSE: 1.356082117989519 | MSE: 1.8389587107309397 | R2: -0.00892520489165638
# Model: SVR-10-2-0.1 | MAE: 1.0910657277299172 | RMSE: 1.3557169406126173 | MSE: 1.8379684230640347 | R2: -0.008381894059605877
# Model: SVR-10-2-1 | MAE: 1.1085993453978062 | RMSE: 1.3506207975335371 | MSE: 1.824176538730128 | R2: -0.0008151229046962083
# Model: SVR-10-3-0.01 | MAE: 1.0907023136032206 | RMSE: 1.356082362391353 | MSE: 1.838959373588913 | R2: -0.008925568561657604
# Model: SVR-10-3-0.1 | MAE: 1.0910654938365163 | RMSE: 1.3557171721368797 | MSE: 1.8379690508268178 | R2: -0.008382238475002968
# Model: SVR-10-3-1 | MAE: 1.108599076561548 | RMSE: 1.3506207392260197 | MSE: 1.8241763812274396 | R2: -0.0008150364925156861
# Model: SVR-10-4-0.01 | MAE: 1.0907023114454875 | RMSE: 1.3560823645947953 | MSE: 1.8389593795650114 | R2: -0.008925571840380675
# Model: SVR-10-4-0.1 | MAE: 1.0910654916177642 | RMSE: 1.3557171743331804 | MSE: 1.8379690567819431 | R2: -0.008382241742219243
# Model: SVR-10-4-1 | MAE: 1.1085990758586803 | RMSE: 1.3506207390735796 | MSE: 1.8241763808156626 | R2: -0.0008150362665984012
# Model: SVR-100-2-0.01 | MAE: 1.090702552995877 | RMSE: 1.35608211792991 | MSE: 1.8389587105692704 | R2: -0.00892520480295822
# Model: SVR-100-2-0.1 | MAE: 1.0910657277877542 | RMSE: 1.3557169405553666 | MSE: 1.8379684229088036 | R2: -0.008381893974440002
# Model: SVR-100-2-1 | MAE: 1.1085993464074833 | RMSE: 1.3506207977525306 | MSE: 1.824176539321682 | R2: -0.0008151232292459287
# Model: SVR-100-3-0.01 | MAE: 1.0907023463716417 | RMSE: 1.3560823289288169 | MSE: 1.8389592828330041 | R2: -0.008925518769390184
# Model: SVR-100-3-0.1 | MAE: 1.0910655266049496 | RMSE: 1.3557171397000782 | MSE: 1.8379689628765612 | R2: -0.008382190222026908
# Model: SVR-100-3-1 | MAE: 1.1085991169720744 | RMSE: 1.3506207479904044 | MSE: 1.8241764049021596 | R2: -0.0008150494813998765
# Model: SVR-100-4-0.01 | MAE: 1.0907023114020573 | RMSE: 1.3560823646391456 | MSE: 1.8389593796852963 | R2: -0.008925571906373664
# Model: SVR-100-4-0.1 | MAE: 1.0910654915667581 | RMSE: 1.3557171743836702 | MSE: 1.837969056918843 | R2: -0.008382241817328051
# Model: SVR-100-4-1 | MAE: 1.1085990759836024 | RMSE: 1.3506207391006733 | MSE: 1.824176380888849 | R2: -0.0008150363067513933
# Model: SVR-1000-2-0.01 | MAE: 1.0907025530504528 | RMSE: 1.3560821178741789 | MSE: 1.8389587104181182 | R2: -0.008925204720030111
# Model: SVR-1000-2-0.1 | MAE: 1.0910657278369609 | RMSE: 1.3557169405066587 | MSE: 1.8379684227767354 | R2: -0.008381893901982185
# Model: SVR-1000-2-1 | MAE: 1.10859934638447 | RMSE: 1.3506207977475393 | MSE: 1.8241765393081992 | R2: -0.0008151232218487348
# Model: SVR-1000-3-0.01 | MAE: 1.0907026740558605 | RMSE: 1.356081994308539 | MSE: 1.8389583752878242 | R2: -0.008925020854346544
# Model: SVR-1000-3-0.1 | MAE: 1.0910658542892728 | RMSE: 1.3557168153371653 | MSE: 1.8379680833879457 | R2: -0.008381707699919971
# Model: SVR-1000-3-1 | MAE: 1.1085995210773607 | RMSE: 1.350620835638097 | MSE: 1.8241766416597516 | R2: -0.0008151793759432202
# Model: SVR-1000-4-0.01 | MAE: 1.0907023111970173 | RMSE: 1.3560823648485292 | MSE: 1.8389593802531792 | R2: -0.008925572217936661
# Model: SVR-1000-4-0.1 | MAE: 1.0910654914727158 | RMSE: 1.3557171744767609 | MSE: 1.8379690571712524 | R2: -0.008382241955809722
# Model: SVR-1000-4-1 | MAE: 1.1085990759382622 | RMSE: 1.3506207390908398 | MSE: 1.8241763808622862 | R2: -0.0008150362921779397
# c:\Users\admin\Documents\GitHub\czasteczkowa-inzynierka\experiments\BACE\No_scaffold\BACE_comparison_results_regression_no_scaffold_pca_svm.csv
# [' RandomForestRegressor-50-None-2-1', ' 2.367922471868426', ' 2.72575634539712', ' 7.4297476544726635', ' -3.0762523001958213']
# ['Model', 'MAE', 'RMSE', 'MSE', 'R2']
